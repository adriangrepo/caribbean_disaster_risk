# %% [markdown]
# ## Train and Prediction on valid data
#
# Using rotated to hz + OpenCv border
#
# Basic default transforms
#
# see:
#
# https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/cnn_archs.ipynb
#
# and
#
# https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/cnn_archs_more.ipynb
#
# mem use 3GB with bs=32 TODO increase

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from torchvision.models import *
from efficientnet_pytorch import EfficientNet
import pretrainedmodels

# %%
from fastai.vision import *
from fastai.vision.models import *
from fastai.vision.learner import model_meta
import geopandas as gpd
from resizeimage import resizeimage
import datetime
import uuid
from os import listdir
from os.path import isfile, join

# %%
__version__
# Out:
# '1.0.59.dev0'

# %%
EFFNET='efficientnet-b6'

# %%
m = EfficientNet.from_pretrained(EFFNET)
# Out:
# Loaded pretrained weights for efficientnet-b6

# %%
def arch_summary(arch):
    model = arch(False)
    tot = 0
    for i, l in enumerate(model.children()):
        n_layers = len(flatten_model(l))
        tot += n_layers
        print(f'({i}) {l.__class__.__name__:<12}: {n_layers:<4}layers (total: {tot})')

# %%
def get_groups(model, layer_groups):
    group_indices = [len(g) for g in layer_groups]
    curr_i = 0
    group = []
    for layer in model:
        group_indices[curr_i] -= len(flatten_model(layer))
        group.append(layer.__class__.__name__)
        if group_indices[curr_i] == 0:
            curr_i += 1
            print(f'Group {curr_i}:', group)   
            group = []

# %%
arch_summary(lambda _: m)
# Out:
# (0) Conv2dStaticSamePadding: 2   layers (total: 2)
# (1) BatchNorm2d : 1   layers (total: 3)
# (2) ModuleList  : 711 layers (total: 714)
# (3) Conv2dStaticSamePadding: 2   layers (total: 716)
# (4) BatchNorm2d : 1   layers (total: 717)
# (5) AdaptiveAvgPool2d: 1   layers (total: 718)
# (6) Dropout     : 1   layers (total: 719)
# (7) Linear      : 1   layers (total: 720)
# (8) MemoryEfficientSwish: 1   layers (total: 721)

# %%
arch_summary(lambda _: list(m.children())[2])
# Out:
# (0) MBConvBlock : 13  layers (total: 13)
# (1) MBConvBlock : 13  layers (total: 26)
# (2) MBConvBlock : 13  layers (total: 39)
# (3) MBConvBlock : 16  layers (total: 55)
# (4) MBConvBlock : 16  layers (total: 71)
# (5) MBConvBlock : 16  layers (total: 87)
# (6) MBConvBlock : 16  layers (total: 103)
# (7) MBConvBlock : 16  layers (total: 119)
# (8) MBConvBlock : 16  layers (total: 135)
# (9) MBConvBlock : 16  layers (total: 151)
# (10) MBConvBlock : 16  layers (total: 167)
# (11) MBConvBlock : 16  layers (total: 183)
# (12) MBConvBlock : 16  layers (total: 199)
# (13) MBConvBlock : 16  layers (total: 215)
# (14) MBConvBlock : 16  layers (total: 231)
# (15) MBConvBlock : 16  layers (total: 247)
# (16) MBConvBlock : 16  layers (total: 263)
# (17) MBConvBlock : 16  layers (total: 279)
# (18) MBConvBlock : 16  layers (total: 295)
# (19) MBConvBlock : 16  layers (total: 311)
# (20) MBConvBlock : 16  layers (total: 327)
# (21) MBConvBlock : 16  layers (total: 343)
# (22) MBConvBlock : 16  layers (total: 359)
# (23) MBConvBlock : 16  layers (total: 375)
# (24) MBConvBlock : 16  layers (total: 391)
# (25) MBConvBlock : 16  layers (total: 407)
# (26) MBConvBlock : 16  layers (total: 423)
# (27) MBConvBlock : 16  layers (total: 439)
# (28) MBConvBlock : 16  layers (total: 455)
# (29) MBConvBlock : 16  layers (total: 471)
# (30) MBConvBlock : 16  layers (total: 487)
# (31) MBConvBlock : 16  layers (total: 503)
# (32) MBConvBlock : 16  layers (total: 519)
# (33) MBConvBlock : 16  layers (total: 535)
# (34) MBConvBlock : 16  layers (total: 551)
# (35) MBConvBlock : 16  layers (total: 567)
# (36) MBConvBlock : 16  layers (total: 583)
# (37) MBConvBlock : 16  layers (total: 599)
# (38) MBConvBlock : 16  layers (total: 615)
# (39) MBConvBlock : 16  layers (total: 631)
# (40) MBConvBlock : 16  layers (total: 647)
# (41) MBConvBlock : 16  layers (total: 663)
# (42) MBConvBlock : 16  layers (total: 679)
# (43) MBConvBlock : 16  layers (total: 695)
# (44) MBConvBlock : 16  layers (total: 711)

# %%
torch.cuda.set_device(2)
torch.cuda.current_device()
# Out:
# 2

# %%
data_dir = Path('data')
colombia_rural = Path('data/stac/colombia/borde_rural')
colombia_soacha = Path('data/stac/colombia/borde_soacha')

# %%
guatemala_mixco1 = Path('data/stac/guatemala/mixco_1_and_ebenezer')
guatemala_mixco3 = Path('data/stac/guatemala/mixco_3')

# %%
st_lucia_castries = Path('data/stac/st_lucia/castries')
st_lucia_dennery = Path('data/stac/st_lucia/dennery')
st_lucia_gros_islet = Path('data/stac/st_lucia/gros_islet')

# %%
COUNTRY='colombia'
REGION='borde_rural'
DATASET = f'{COUNTRY}_{REGION}'
DATASET_PATH=colombia_rural
path=data_dir/f'{COUNTRY}_{REGION}/cropped/'
TRAIN_JSON = f'train-{REGION}.geojson'
TEST_JSON = f'test-{REGION}.geojson'

# %%
RETRAIN = True
RESIZE_IMAGES = True

# %%
MODEL_NAME='efficientnet'

# %%
NB_NUM='06_10'

# %%
DATE = datetime.datetime.today().strftime('%Y%m%d')
UID=str(uuid.uuid4())[:8]
print(f'UID: {UID}, DATE: {DATE}')
# Out:
# UID: 226fd156, DATE: 20191119

# %%
DATE = '20191118'
UID = '3bea6f60'

# %%
SUB_NUM='24'

# %%
img_size=256
bs=32

# %%
train_images=data_dir/f'train/rotated/clipped/{img_size}'
test_images=data_dir/f'test/rotated/clipped/{img_size}'

# %%
test_names = get_image_files(test_images)

# %%
assert len(test_names)==7325

# %%
df_all=pd.read_csv(data_dir/'df_train_all.csv')

# %%
df_all.tail()
# Out:
#              id  roof_material  verified   country      region
# 22548  7a22ddec  healthy_metal     False  st_lucia  gros_islet
# 22549  7a2f73ea  healthy_metal     False  st_lucia  gros_islet
# 22550  7a34ffa4  healthy_metal     False  st_lucia  gros_islet
# 22551  7a41560a  healthy_metal     False  st_lucia  gros_islet
# 22552  7a283ad0  healthy_metal     False  st_lucia  gros_islet

# %%
df_valid=df_all.loc[df_all['verified'] == True]

# %%
df_test=pd.read_csv(data_dir/'df_test_all.csv')

# %%
df_test.tail()
# Out:
#             id   country   region
# 7320  7a4f3ff4  st_lucia  dennery
# 7321  7a4fc578  st_lucia  dennery
# 7322  7a4ac7b2  st_lucia  dennery
# 7323  7a47e25e  st_lucia  dennery
# 7324  7a4e3f78  st_lucia  dennery

# %%
assert len(df_test)==7325

# %%
df_all.loc[df_all['id'] == '7a204ec4']
# Out:
#              id    roof_material  verified    country                region
# 12960  7a204ec4  irregular_metal      True  guatemala  mixco_1_and_ebenezer

# %%
len(df_all)
# Out:
# 22553

# %% [markdown]
# To put this in a `DataBunch` while using the [data block API](https://docs.fast.ai/data_block.html), we then need to using `ImageList` (and not `ImageDataBunch`). This will make sure the model created has the proper loss function to deal with the multiple classes.

# %%
xtra_tfms=[dihedral(p=0.7), rand_crop(p=0.4)]
tfms = get_transforms(flip_vert=True, max_lighting=0.2, max_zoom=1.1, max_warp=0., xtra_tfms=xtra_tfms)
#tfms = get_transforms(flip_vert=True, max_lighting=0.1, max_zoom=1.05, max_warp=0.)

# %% [markdown]
# ### setup dataset

# %%
np.random.seed(42)
dep_var='roof_material'
src = (ImageList.from_df(path=train_images, df=df_valid, cols='id', suffix='.tif')
       .split_by_rand_pct(0.1)
      .label_from_df(cols=dep_var)
      .add_test_folder(test_images))

# %%
data = (src.transform(tfms, size=img_size)
        .databunch(bs=bs).normalize(imagenet_stats))

# %%
#to check what params object has
#dir(data)

# %%
data.label_list
# Out:
# LabelLists;
#
# Train: LabelList (13383 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (1487 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# healthy_metal,concrete_cement,irregular_metal,irregular_metal,concrete_cement
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256

# %%
data.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %% [markdown]
# `show_batch` still works, and show us the different labels separated by `;`.

# %%
data.show_batch(rows=3, figsize=(12,9))

# %%
def get_groups(model, layer_groups):
    group_indices = [len(g) for g in layer_groups]
    curr_i = 0
    group = []
    for layer in model:
        group_indices[curr_i] -= len(flatten_model(layer))
        group.append(layer.__class__.__name__)
        if group_indices[curr_i] == 0:
            curr_i += 1
            print(f'Group {curr_i}:', group)   
            group = []

# %% [markdown]
# ### Model

# %%
# "pretrained" is hardcoded to adapt to the PyTorch model function
def efficient_net_b6(pretrained=True):
    model = EfficientNet.from_pretrained(EFFNET)
    return nn.Sequential(model)

# %%
model_meta[efficient_net_b6] =  { 'cut': noop, 
                               'split': lambda m: (list(m[0][0].children())[2][7], m[1]) }

# %%
list(efficient_net_b6()[0].children())
# Out:
# Loaded pretrained weights for efficientnet-b6
# [Conv2dStaticSamePadding(
#    3, 56, kernel_size=(3, 3), stride=(2, 2), bias=False
#    (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#  ),
#  BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True),
#  ModuleList(
#    (0): MBConvBlock(
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        56, 14, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        14, 56, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (1): MBConvBlock(
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        32, 8, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        8, 32, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (2): MBConvBlock(
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        32, 8, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        8, 32, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (3): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#        (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        192, 8, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        8, 192, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (4): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (5): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (6): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (7): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (8): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (9): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (10): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        432, 18, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        18, 432, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (11): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        432, 18, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        18, 432, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (12): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        432, 18, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        18, 432, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (13): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        432, 18, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        18, 432, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (14): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        432, 18, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        18, 432, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (15): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#        (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        432, 18, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        18, 432, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (16): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (17): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (18): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (19): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (20): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (21): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (22): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (23): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        864, 36, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        36, 864, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (24): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (25): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (26): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (27): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (28): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (29): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (30): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (31): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1200, 50, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        50, 1200, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (32): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (33): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (34): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (35): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (36): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (37): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (38): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (39): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (40): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (41): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (42): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        2064, 2064, kernel_size=(3, 3), stride=[1, 1], groups=2064, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        2064, 86, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        86, 2064, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        2064, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (43): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        3456, 3456, kernel_size=(3, 3), stride=(1, 1), groups=3456, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        3456, 144, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        144, 3456, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (44): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        576, 3456, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        3456, 3456, kernel_size=(3, 3), stride=(1, 1), groups=3456, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        3456, 144, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        144, 3456, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        3456, 576, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#  ),
#  Conv2dStaticSamePadding(
#    576, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#    (static_padding): Identity()
#  ),
#  BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True),
#  AdaptiveAvgPool2d(output_size=1),
#  Dropout(p=0.5, inplace=False),
#  Linear(in_features=2304, out_features=1000, bias=True),
#  MemoryEfficientSwish()]

# %%
output_size = list(efficient_net_b6()[0].children())[-2].out_features
# Out:
# Loaded pretrained weights for efficientnet-b6

# %%
output_size
# Out:
# 1000

# %%
custom_head = nn.Linear(output_size, data.c)

# %%
arch = efficient_net_b6
arch_name = EFFNET

# %%
learn = cnn_learner(data, arch, custom_head = custom_head, metrics=error_rate, bn_final=True).to_fp16()
# Out:
# Loaded pretrained weights for efficientnet-b6

# %%
get_groups(nn.Sequential(*list(learn.model[0][0].children())[:2], 
                         *list(learn.model[0][0].children())[2],
                         *list(learn.model[0][0].children())[3:],
                         learn.model[1]), 
           learn.layer_groups)
# Out:
# Group 1: ['Conv2dStaticSamePadding', 'BatchNorm2d', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock']
# Group 2: ['MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'Conv2dStaticSamePadding', 'BatchNorm2d', 'AdaptiveAvgPool2d', 'Dropout', 'Linear', 'MemoryEfficientSwish']
# Group 3: ['Linear']

# %%
#learn.model = torch.nn.DataParallel(learn.model, device_ids=[0, 1, 2])

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %% [markdown]
# ### train model

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# Then we can fit the head of our network.

# %%
lr = 5e-3

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.075695</td>
#       <td>0.944351</td>
#       <td>0.371217</td>
#       <td>03:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.001102</td>
#       <td>0.887100</td>
#       <td>0.329523</td>
#       <td>03:42</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.834899</td>
#       <td>0.753024</td>
#       <td>0.283793</td>
#       <td>03:40</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.726214</td>
#       <td>0.663585</td>
#       <td>0.256221</td>
#       <td>03:36</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.675940</td>
#       <td>0.651676</td>
#       <td>0.252186</td>
#       <td>03:35</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.779632</td>
#       <td>0.688660</td>
#       <td>0.262273</td>
#       <td>03:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.749258</td>
#       <td>0.675918</td>
#       <td>0.264963</td>
#       <td>03:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.719724</td>
#       <td>0.638939</td>
#       <td>0.254876</td>
#       <td>03:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.666684</td>
#       <td>0.595587</td>
#       <td>0.238063</td>
#       <td>03:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.606402</td>
#       <td>0.584745</td>
#       <td>0.223268</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.660341</td>
#       <td>0.607958</td>
#       <td>0.234701</td>
#       <td>03:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.667877</td>
#       <td>0.647618</td>
#       <td>0.260256</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.657148</td>
#       <td>0.604264</td>
#       <td>0.234028</td>
#       <td>02:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.618971</td>
#       <td>0.569773</td>
#       <td>0.220578</td>
#       <td>03:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.594340</td>
#       <td>0.565094</td>
#       <td>0.221923</td>
#       <td>03:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1c-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %% [markdown]
# #### Load model

# %%
learn.load(f'stage-1c-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (13383 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (1487 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# healthy_metal,concrete_cement,irregular_metal,irregular_metal,concrete_cement
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256, model=Sequential(
#   (0): Sequential(
#     (0): EfficientNet(
#       (_conv_stem): Conv2dStaticSamePadding(
#         3, 56, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn0): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_blocks): ModuleList(
#         (0): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             56, 14, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             14, 56, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (1): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (2): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (3): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             192, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 192, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (4): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (5): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (6): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (7): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (8): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (9): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (10): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (11): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (12): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (13): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (14): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (15): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (16): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (17): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (18): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (19): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (20): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (21): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (22): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (23): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (24): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (25): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (26): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (27): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (28): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (29): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (30): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (31): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (32): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (33): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (34): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (35): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (36): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
# ...
#   (240): Identity()
#   (241): ParameterModule()
#   (242): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (244): ParameterModule()
#   (245): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): ParameterModule()
#   (252): Identity()
#   (253): ParameterModule()
#   (254): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (255): MemoryEfficientSwish()
#   (256): Identity()
#   (257): ParameterModule()
#   (258): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (260): ParameterModule()
#   (261): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): ParameterModule()
#   (268): Identity()
#   (269): ParameterModule()
#   (270): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (271): MemoryEfficientSwish()
#   (272): Identity()
#   (273): ParameterModule()
#   (274): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (276): ParameterModule()
#   (277): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): ParameterModule()
#   (284): Identity()
#   (285): ParameterModule()
#   (286): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (287): MemoryEfficientSwish()
#   (288): Identity()
#   (289): ParameterModule()
#   (290): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (292): ParameterModule()
#   (293): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): ParameterModule()
#   (300): Identity()
#   (301): ParameterModule()
#   (302): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (303): MemoryEfficientSwish()
#   (304): Identity()
#   (305): ParameterModule()
#   (306): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (308): ParameterModule()
#   (309): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): ParameterModule()
#   (316): Identity()
#   (317): ParameterModule()
#   (318): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (319): MemoryEfficientSwish()
#   (320): Identity()
#   (321): ParameterModule()
#   (322): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (324): ParameterModule()
#   (325): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): ParameterModule()
#   (332): Identity()
#   (333): ParameterModule()
#   (334): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (335): MemoryEfficientSwish()
#   (336): Identity()
#   (337): ParameterModule()
#   (338): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (340): ParameterModule()
#   (341): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): ParameterModule()
#   (348): Identity()
#   (349): ParameterModule()
#   (350): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (351): MemoryEfficientSwish()
#   (352): Identity()
#   (353): ParameterModule()
#   (354): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (356): ParameterModule()
#   (357): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): ParameterModule()
#   (364): Identity()
#   (365): ParameterModule()
#   (366): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (367): MemoryEfficientSwish()
#   (368): Identity()
#   (369): ParameterModule()
#   (370): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (371): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (372): ParameterModule()
#   (373): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (374): Identity()
#   (375): ParameterModule()
#   (376): ParameterModule()
#   (377): Identity()
#   (378): ParameterModule()
#   (379): ParameterModule()
#   (380): Identity()
#   (381): ParameterModule()
#   (382): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (383): MemoryEfficientSwish()
#   (384): Identity()
#   (385): ParameterModule()
#   (386): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (387): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (388): ParameterModule()
#   (389): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (390): Identity()
#   (391): ParameterModule()
#   (392): ParameterModule()
#   (393): Identity()
#   (394): ParameterModule()
#   (395): ParameterModule()
#   (396): Identity()
#   (397): ParameterModule()
#   (398): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (399): MemoryEfficientSwish()
#   (400): Identity()
#   (401): ParameterModule()
#   (402): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (403): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (404): ParameterModule()
#   (405): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (406): Identity()
#   (407): ParameterModule()
#   (408): ParameterModule()
#   (409): Identity()
#   (410): ParameterModule()
#   (411): ParameterModule()
#   (412): Identity()
#   (413): ParameterModule()
#   (414): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (415): MemoryEfficientSwish()
#   (416): Identity()
#   (417): ParameterModule()
#   (418): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (419): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (420): ParameterModule()
#   (421): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (422): Identity()
#   (423): ParameterModule()
#   (424): ParameterModule()
#   (425): Identity()
#   (426): ParameterModule()
#   (427): ParameterModule()
#   (428): Identity()
#   (429): ParameterModule()
#   (430): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (431): MemoryEfficientSwish()
#   (432): Identity()
#   (433): ParameterModule()
#   (434): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (435): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (436): ParameterModule()
#   (437): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (438): Identity()
#   (439): ParameterModule()
#   (440): ParameterModule()
#   (441): Identity()
#   (442): ParameterModule()
#   (443): ParameterModule()
#   (444): Identity()
#   (445): ParameterModule()
#   (446): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (447): MemoryEfficientSwish()
#   (448): Identity()
#   (449): ParameterModule()
#   (450): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (451): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (452): ParameterModule()
#   (453): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (454): Identity()
#   (455): ParameterModule()
#   (456): ParameterModule()
#   (457): Identity()
#   (458): ParameterModule()
#   (459): ParameterModule()
#   (460): Identity()
#   (461): ParameterModule()
#   (462): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (463): MemoryEfficientSwish()
#   (464): Identity()
#   (465): ParameterModule()
#   (466): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (467): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (468): ParameterModule()
#   (469): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (470): Identity()
#   (471): ParameterModule()
#   (472): ParameterModule()
#   (473): Identity()
#   (474): ParameterModule()
#   (475): ParameterModule()
#   (476): Identity()
#   (477): ParameterModule()
#   (478): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (479): MemoryEfficientSwish()
#   (480): Identity()
#   (481): ParameterModule()
#   (482): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (483): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (484): ParameterModule()
#   (485): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (486): Identity()
#   (487): ParameterModule()
#   (488): ParameterModule()
#   (489): Identity()
#   (490): ParameterModule()
#   (491): ParameterModule()
#   (492): Identity()
#   (493): ParameterModule()
#   (494): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (495): MemoryEfficientSwish()
#   (496): Identity()
#   (497): ParameterModule()
#   (498): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (499): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (500): ParameterModule()
#   (501): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (502): Identity()
#   (503): ParameterModule()
#   (504): ParameterModule()
#   (505): Identity()
#   (506): ParameterModule()
#   (507): ParameterModule()
#   (508): Identity()
#   (509): ParameterModule()
#   (510): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (511): MemoryEfficientSwish()
#   (512): Identity()
#   (513): ParameterModule()
#   (514): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (515): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (516): ParameterModule()
#   (517): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (518): Identity()
#   (519): ParameterModule()
#   (520): ParameterModule()
#   (521): Identity()
#   (522): ParameterModule()
#   (523): ParameterModule()
#   (524): Identity()
#   (525): ParameterModule()
#   (526): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (527): MemoryEfficientSwish()
#   (528): Identity()
#   (529): ParameterModule()
#   (530): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (531): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (532): ParameterModule()
#   (533): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (534): Identity()
#   (535): ParameterModule()
#   (536): ParameterModule()
#   (537): Identity()
#   (538): ParameterModule()
#   (539): ParameterModule()
#   (540): Identity()
#   (541): ParameterModule()
#   (542): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (543): MemoryEfficientSwish()
#   (544): Identity()
#   (545): ParameterModule()
#   (546): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (547): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (548): ParameterModule()
#   (549): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (550): Identity()
#   (551): ParameterModule()
#   (552): ParameterModule()
#   (553): Identity()
#   (554): ParameterModule()
#   (555): ParameterModule()
#   (556): Identity()
#   (557): ParameterModule()
#   (558): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (559): MemoryEfficientSwish()
#   (560): Identity()
#   (561): ParameterModule()
#   (562): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (563): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (564): ParameterModule()
#   (565): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (566): Identity()
#   (567): ParameterModule()
#   (568): ParameterModule()
#   (569): Identity()
#   (570): ParameterModule()
#   (571): ParameterModule()
#   (572): Identity()
#   (573): ParameterModule()
#   (574): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (575): MemoryEfficientSwish()
#   (576): Identity()
#   (577): ParameterModule()
#   (578): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (579): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (580): ParameterModule()
#   (581): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): Identity()
#   (583): ParameterModule()
#   (584): ParameterModule()
#   (585): Identity()
#   (586): ParameterModule()
#   (587): ParameterModule()
#   (588): Identity()
#   (589): ParameterModule()
#   (590): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (591): MemoryEfficientSwish()
#   (592): Identity()
#   (593): ParameterModule()
#   (594): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (595): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (596): ParameterModule()
#   (597): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (598): Identity()
#   (599): ParameterModule()
#   (600): ParameterModule()
#   (601): Identity()
#   (602): ParameterModule()
#   (603): ParameterModule()
#   (604): Identity()
#   (605): ParameterModule()
#   (606): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (607): MemoryEfficientSwish()
#   (608): Identity()
#   (609): ParameterModule()
#   (610): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (611): AdaptiveAvgPool2d(output_size=1)
#   (612): Dropout(p=0.5, inplace=False)
#   (613): Linear(in_features=2304, out_features=1000, bias=True)
#   (614): MemoryEfficientSwish()
# ), Sequential(
#   (0): Linear(in_features=1000, out_features=5, bias=True)
# )], add_time=True, silent=False)

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.most_confused(min_val=2)
# Out:
# [('irregular_metal', 'healthy_metal', 128),
#  ('healthy_metal', 'irregular_metal', 80),
#  ('incomplete', 'irregular_metal', 28),
#  ('concrete_cement', 'healthy_metal', 17),
#  ('irregular_metal', 'concrete_cement', 12),
#  ('incomplete', 'concrete_cement', 10),
#  ('concrete_cement', 'irregular_metal', 9),
#  ('healthy_metal', 'concrete_cement', 9),
#  ('irregular_metal', 'incomplete', 9),
#  ('other', 'healthy_metal', 8),
#  ('concrete_cement', 'incomplete', 6),
#  ('other', 'irregular_metal', 6),
#  ('incomplete', 'healthy_metal', 4),
#  ('irregular_metal', 'other', 2)]

# %%
interp.plot_confusion_matrix(figsize=(10,10), dpi=60)

# %% [markdown]
# ### Re-train

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.603260</td>
#       <td>0.549891</td>
#       <td>0.213853</td>
#       <td>04:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.554797</td>
#       <td>0.527180</td>
#       <td>0.205111</td>
#       <td>04:14</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.501618</td>
#       <td>0.512498</td>
#       <td>0.186281</td>
#       <td>04:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.398711</td>
#       <td>0.515530</td>
#       <td>0.190989</td>
#       <td>04:13</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.388064</td>
#       <td>0.521145</td>
#       <td>0.190316</td>
#       <td>04:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.load(f'stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (13383 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (1487 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# healthy_metal,concrete_cement,irregular_metal,irregular_metal,concrete_cement
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256, model=Sequential(
#   (0): Sequential(
#     (0): EfficientNet(
#       (_conv_stem): Conv2dStaticSamePadding(
#         3, 56, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn0): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_blocks): ModuleList(
#         (0): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             56, 14, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             14, 56, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (1): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (2): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (3): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             192, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 192, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (4): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (5): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (6): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (7): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (8): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (9): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (10): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (11): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (12): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (13): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (14): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (15): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (16): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (17): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (18): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (19): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (20): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (21): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (22): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (23): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (24): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (25): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (26): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (27): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (28): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (29): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (30): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (31): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (32): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (33): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (34): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (35): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (36): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
# ...
#   (240): Identity()
#   (241): ParameterModule()
#   (242): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (244): ParameterModule()
#   (245): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): ParameterModule()
#   (252): Identity()
#   (253): ParameterModule()
#   (254): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (255): MemoryEfficientSwish()
#   (256): Identity()
#   (257): ParameterModule()
#   (258): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (260): ParameterModule()
#   (261): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): ParameterModule()
#   (268): Identity()
#   (269): ParameterModule()
#   (270): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (271): MemoryEfficientSwish()
#   (272): Identity()
#   (273): ParameterModule()
#   (274): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (276): ParameterModule()
#   (277): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): ParameterModule()
#   (284): Identity()
#   (285): ParameterModule()
#   (286): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (287): MemoryEfficientSwish()
#   (288): Identity()
#   (289): ParameterModule()
#   (290): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (292): ParameterModule()
#   (293): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): ParameterModule()
#   (300): Identity()
#   (301): ParameterModule()
#   (302): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (303): MemoryEfficientSwish()
#   (304): Identity()
#   (305): ParameterModule()
#   (306): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (308): ParameterModule()
#   (309): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): ParameterModule()
#   (316): Identity()
#   (317): ParameterModule()
#   (318): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (319): MemoryEfficientSwish()
#   (320): Identity()
#   (321): ParameterModule()
#   (322): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (324): ParameterModule()
#   (325): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): ParameterModule()
#   (332): Identity()
#   (333): ParameterModule()
#   (334): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (335): MemoryEfficientSwish()
#   (336): Identity()
#   (337): ParameterModule()
#   (338): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (340): ParameterModule()
#   (341): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): ParameterModule()
#   (348): Identity()
#   (349): ParameterModule()
#   (350): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (351): MemoryEfficientSwish()
#   (352): Identity()
#   (353): ParameterModule()
#   (354): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (356): ParameterModule()
#   (357): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): ParameterModule()
#   (364): Identity()
#   (365): ParameterModule()
#   (366): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (367): MemoryEfficientSwish()
#   (368): Identity()
#   (369): ParameterModule()
#   (370): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (371): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (372): ParameterModule()
#   (373): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (374): Identity()
#   (375): ParameterModule()
#   (376): ParameterModule()
#   (377): Identity()
#   (378): ParameterModule()
#   (379): ParameterModule()
#   (380): Identity()
#   (381): ParameterModule()
#   (382): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (383): MemoryEfficientSwish()
#   (384): Identity()
#   (385): ParameterModule()
#   (386): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (387): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (388): ParameterModule()
#   (389): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (390): Identity()
#   (391): ParameterModule()
#   (392): ParameterModule()
#   (393): Identity()
#   (394): ParameterModule()
#   (395): ParameterModule()
#   (396): Identity()
#   (397): ParameterModule()
#   (398): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (399): MemoryEfficientSwish()
#   (400): Identity()
#   (401): ParameterModule()
#   (402): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (403): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (404): ParameterModule()
#   (405): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (406): Identity()
#   (407): ParameterModule()
#   (408): ParameterModule()
#   (409): Identity()
#   (410): ParameterModule()
#   (411): ParameterModule()
#   (412): Identity()
#   (413): ParameterModule()
#   (414): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (415): MemoryEfficientSwish()
#   (416): Identity()
#   (417): ParameterModule()
#   (418): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (419): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (420): ParameterModule()
#   (421): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (422): Identity()
#   (423): ParameterModule()
#   (424): ParameterModule()
#   (425): Identity()
#   (426): ParameterModule()
#   (427): ParameterModule()
#   (428): Identity()
#   (429): ParameterModule()
#   (430): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (431): MemoryEfficientSwish()
#   (432): Identity()
#   (433): ParameterModule()
#   (434): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (435): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (436): ParameterModule()
#   (437): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (438): Identity()
#   (439): ParameterModule()
#   (440): ParameterModule()
#   (441): Identity()
#   (442): ParameterModule()
#   (443): ParameterModule()
#   (444): Identity()
#   (445): ParameterModule()
#   (446): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (447): MemoryEfficientSwish()
#   (448): Identity()
#   (449): ParameterModule()
#   (450): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (451): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (452): ParameterModule()
#   (453): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (454): Identity()
#   (455): ParameterModule()
#   (456): ParameterModule()
#   (457): Identity()
#   (458): ParameterModule()
#   (459): ParameterModule()
#   (460): Identity()
#   (461): ParameterModule()
#   (462): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (463): MemoryEfficientSwish()
#   (464): Identity()
#   (465): ParameterModule()
#   (466): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (467): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (468): ParameterModule()
#   (469): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (470): Identity()
#   (471): ParameterModule()
#   (472): ParameterModule()
#   (473): Identity()
#   (474): ParameterModule()
#   (475): ParameterModule()
#   (476): Identity()
#   (477): ParameterModule()
#   (478): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (479): MemoryEfficientSwish()
#   (480): Identity()
#   (481): ParameterModule()
#   (482): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (483): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (484): ParameterModule()
#   (485): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (486): Identity()
#   (487): ParameterModule()
#   (488): ParameterModule()
#   (489): Identity()
#   (490): ParameterModule()
#   (491): ParameterModule()
#   (492): Identity()
#   (493): ParameterModule()
#   (494): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (495): MemoryEfficientSwish()
#   (496): Identity()
#   (497): ParameterModule()
#   (498): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (499): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (500): ParameterModule()
#   (501): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (502): Identity()
#   (503): ParameterModule()
#   (504): ParameterModule()
#   (505): Identity()
#   (506): ParameterModule()
#   (507): ParameterModule()
#   (508): Identity()
#   (509): ParameterModule()
#   (510): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (511): MemoryEfficientSwish()
#   (512): Identity()
#   (513): ParameterModule()
#   (514): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (515): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (516): ParameterModule()
#   (517): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (518): Identity()
#   (519): ParameterModule()
#   (520): ParameterModule()
#   (521): Identity()
#   (522): ParameterModule()
#   (523): ParameterModule()
#   (524): Identity()
#   (525): ParameterModule()
#   (526): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (527): MemoryEfficientSwish()
#   (528): Identity()
#   (529): ParameterModule()
#   (530): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (531): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (532): ParameterModule()
#   (533): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (534): Identity()
#   (535): ParameterModule()
#   (536): ParameterModule()
#   (537): Identity()
#   (538): ParameterModule()
#   (539): ParameterModule()
#   (540): Identity()
#   (541): ParameterModule()
#   (542): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (543): MemoryEfficientSwish()
#   (544): Identity()
#   (545): ParameterModule()
#   (546): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (547): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (548): ParameterModule()
#   (549): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (550): Identity()
#   (551): ParameterModule()
#   (552): ParameterModule()
#   (553): Identity()
#   (554): ParameterModule()
#   (555): ParameterModule()
#   (556): Identity()
#   (557): ParameterModule()
#   (558): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (559): MemoryEfficientSwish()
#   (560): Identity()
#   (561): ParameterModule()
#   (562): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (563): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (564): ParameterModule()
#   (565): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (566): Identity()
#   (567): ParameterModule()
#   (568): ParameterModule()
#   (569): Identity()
#   (570): ParameterModule()
#   (571): ParameterModule()
#   (572): Identity()
#   (573): ParameterModule()
#   (574): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (575): MemoryEfficientSwish()
#   (576): Identity()
#   (577): ParameterModule()
#   (578): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (579): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (580): ParameterModule()
#   (581): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): Identity()
#   (583): ParameterModule()
#   (584): ParameterModule()
#   (585): Identity()
#   (586): ParameterModule()
#   (587): ParameterModule()
#   (588): Identity()
#   (589): ParameterModule()
#   (590): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (591): MemoryEfficientSwish()
#   (592): Identity()
#   (593): ParameterModule()
#   (594): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (595): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (596): ParameterModule()
#   (597): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (598): Identity()
#   (599): ParameterModule()
#   (600): ParameterModule()
#   (601): Identity()
#   (602): ParameterModule()
#   (603): ParameterModule()
#   (604): Identity()
#   (605): ParameterModule()
#   (606): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (607): MemoryEfficientSwish()
#   (608): Identity()
#   (609): ParameterModule()
#   (610): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (611): AdaptiveAvgPool2d(output_size=1)
#   (612): Dropout(p=0.5, inplace=False)
#   (613): Linear(in_features=2304, out_features=1000, bias=True)
#   (614): MemoryEfficientSwish()
# ), Sequential(
#   (0): Linear(in_features=1000, out_features=5, bias=True)
# )], add_time=True, silent=False)

# %%
#learn.fit_one_cycle(5, slice(1e-5, lr/5))

# %%
learn.recorder.plot_losses()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-dcd199964d48> in <module>
# ----> 1 learn.recorder.plot_losses()
#
# AttributeError: 'Learner' object has no attribute 'recorder'

# %%
#learn.save(f'stage-2b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
#learn.load(f'stage-2b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
#learn = learn.to_fp32()

# %%
#learn.export(f'stage-2b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.pkl')

# %%
#learn.export()

# %% [markdown]
# ### 20191030 up to here, TOTO inference

# %% [markdown]
# ### Larger size images

# %%
bs=8

# %%
data = (src.transform(tfms, size=512)
        .databunch(bs=bs).normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 512, 512])

# %%
learn.to_fp16()
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (13383 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (1487 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# healthy_metal,concrete_cement,irregular_metal,irregular_metal,concrete_cement
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256, model=Sequential(
#   (0): Sequential(
#     (0): EfficientNet(
#       (_conv_stem): Conv2dStaticSamePadding(
#         3, 56, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn0): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_blocks): ModuleList(
#         (0): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             56, 14, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             14, 56, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (1): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (2): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (3): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             192, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 192, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (4): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (5): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (6): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (7): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (8): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (9): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (10): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (11): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (12): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (13): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (14): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (15): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (16): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (17): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (18): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (19): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (20): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (21): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (22): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (23): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (24): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (25): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (26): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (27): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (28): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (29): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (30): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (31): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (32): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (33): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (34): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (35): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (36): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
# ...
#   (240): Identity()
#   (241): ParameterModule()
#   (242): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (244): ParameterModule()
#   (245): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): ParameterModule()
#   (252): Identity()
#   (253): ParameterModule()
#   (254): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (255): MemoryEfficientSwish()
#   (256): Identity()
#   (257): ParameterModule()
#   (258): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (260): ParameterModule()
#   (261): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): ParameterModule()
#   (268): Identity()
#   (269): ParameterModule()
#   (270): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (271): MemoryEfficientSwish()
#   (272): Identity()
#   (273): ParameterModule()
#   (274): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (276): ParameterModule()
#   (277): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): ParameterModule()
#   (284): Identity()
#   (285): ParameterModule()
#   (286): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (287): MemoryEfficientSwish()
#   (288): Identity()
#   (289): ParameterModule()
#   (290): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (292): ParameterModule()
#   (293): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): ParameterModule()
#   (300): Identity()
#   (301): ParameterModule()
#   (302): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (303): MemoryEfficientSwish()
#   (304): Identity()
#   (305): ParameterModule()
#   (306): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (308): ParameterModule()
#   (309): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): ParameterModule()
#   (316): Identity()
#   (317): ParameterModule()
#   (318): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (319): MemoryEfficientSwish()
#   (320): Identity()
#   (321): ParameterModule()
#   (322): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (324): ParameterModule()
#   (325): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): ParameterModule()
#   (332): Identity()
#   (333): ParameterModule()
#   (334): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (335): MemoryEfficientSwish()
#   (336): Identity()
#   (337): ParameterModule()
#   (338): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (340): ParameterModule()
#   (341): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): ParameterModule()
#   (348): Identity()
#   (349): ParameterModule()
#   (350): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (351): MemoryEfficientSwish()
#   (352): Identity()
#   (353): ParameterModule()
#   (354): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (356): ParameterModule()
#   (357): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): ParameterModule()
#   (364): Identity()
#   (365): ParameterModule()
#   (366): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (367): MemoryEfficientSwish()
#   (368): Identity()
#   (369): ParameterModule()
#   (370): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (371): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (372): ParameterModule()
#   (373): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (374): Identity()
#   (375): ParameterModule()
#   (376): ParameterModule()
#   (377): Identity()
#   (378): ParameterModule()
#   (379): ParameterModule()
#   (380): Identity()
#   (381): ParameterModule()
#   (382): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (383): MemoryEfficientSwish()
#   (384): Identity()
#   (385): ParameterModule()
#   (386): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (387): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (388): ParameterModule()
#   (389): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (390): Identity()
#   (391): ParameterModule()
#   (392): ParameterModule()
#   (393): Identity()
#   (394): ParameterModule()
#   (395): ParameterModule()
#   (396): Identity()
#   (397): ParameterModule()
#   (398): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (399): MemoryEfficientSwish()
#   (400): Identity()
#   (401): ParameterModule()
#   (402): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (403): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (404): ParameterModule()
#   (405): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (406): Identity()
#   (407): ParameterModule()
#   (408): ParameterModule()
#   (409): Identity()
#   (410): ParameterModule()
#   (411): ParameterModule()
#   (412): Identity()
#   (413): ParameterModule()
#   (414): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (415): MemoryEfficientSwish()
#   (416): Identity()
#   (417): ParameterModule()
#   (418): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (419): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (420): ParameterModule()
#   (421): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (422): Identity()
#   (423): ParameterModule()
#   (424): ParameterModule()
#   (425): Identity()
#   (426): ParameterModule()
#   (427): ParameterModule()
#   (428): Identity()
#   (429): ParameterModule()
#   (430): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (431): MemoryEfficientSwish()
#   (432): Identity()
#   (433): ParameterModule()
#   (434): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (435): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (436): ParameterModule()
#   (437): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (438): Identity()
#   (439): ParameterModule()
#   (440): ParameterModule()
#   (441): Identity()
#   (442): ParameterModule()
#   (443): ParameterModule()
#   (444): Identity()
#   (445): ParameterModule()
#   (446): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (447): MemoryEfficientSwish()
#   (448): Identity()
#   (449): ParameterModule()
#   (450): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (451): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (452): ParameterModule()
#   (453): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (454): Identity()
#   (455): ParameterModule()
#   (456): ParameterModule()
#   (457): Identity()
#   (458): ParameterModule()
#   (459): ParameterModule()
#   (460): Identity()
#   (461): ParameterModule()
#   (462): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (463): MemoryEfficientSwish()
#   (464): Identity()
#   (465): ParameterModule()
#   (466): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (467): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (468): ParameterModule()
#   (469): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (470): Identity()
#   (471): ParameterModule()
#   (472): ParameterModule()
#   (473): Identity()
#   (474): ParameterModule()
#   (475): ParameterModule()
#   (476): Identity()
#   (477): ParameterModule()
#   (478): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (479): MemoryEfficientSwish()
#   (480): Identity()
#   (481): ParameterModule()
#   (482): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (483): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (484): ParameterModule()
#   (485): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (486): Identity()
#   (487): ParameterModule()
#   (488): ParameterModule()
#   (489): Identity()
#   (490): ParameterModule()
#   (491): ParameterModule()
#   (492): Identity()
#   (493): ParameterModule()
#   (494): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (495): MemoryEfficientSwish()
#   (496): Identity()
#   (497): ParameterModule()
#   (498): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (499): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (500): ParameterModule()
#   (501): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (502): Identity()
#   (503): ParameterModule()
#   (504): ParameterModule()
#   (505): Identity()
#   (506): ParameterModule()
#   (507): ParameterModule()
#   (508): Identity()
#   (509): ParameterModule()
#   (510): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (511): MemoryEfficientSwish()
#   (512): Identity()
#   (513): ParameterModule()
#   (514): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (515): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (516): ParameterModule()
#   (517): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (518): Identity()
#   (519): ParameterModule()
#   (520): ParameterModule()
#   (521): Identity()
#   (522): ParameterModule()
#   (523): ParameterModule()
#   (524): Identity()
#   (525): ParameterModule()
#   (526): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (527): MemoryEfficientSwish()
#   (528): Identity()
#   (529): ParameterModule()
#   (530): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (531): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (532): ParameterModule()
#   (533): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (534): Identity()
#   (535): ParameterModule()
#   (536): ParameterModule()
#   (537): Identity()
#   (538): ParameterModule()
#   (539): ParameterModule()
#   (540): Identity()
#   (541): ParameterModule()
#   (542): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (543): MemoryEfficientSwish()
#   (544): Identity()
#   (545): ParameterModule()
#   (546): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (547): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (548): ParameterModule()
#   (549): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (550): Identity()
#   (551): ParameterModule()
#   (552): ParameterModule()
#   (553): Identity()
#   (554): ParameterModule()
#   (555): ParameterModule()
#   (556): Identity()
#   (557): ParameterModule()
#   (558): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (559): MemoryEfficientSwish()
#   (560): Identity()
#   (561): ParameterModule()
#   (562): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (563): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (564): ParameterModule()
#   (565): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (566): Identity()
#   (567): ParameterModule()
#   (568): ParameterModule()
#   (569): Identity()
#   (570): ParameterModule()
#   (571): ParameterModule()
#   (572): Identity()
#   (573): ParameterModule()
#   (574): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (575): MemoryEfficientSwish()
#   (576): Identity()
#   (577): ParameterModule()
#   (578): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (579): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (580): ParameterModule()
#   (581): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): Identity()
#   (583): ParameterModule()
#   (584): ParameterModule()
#   (585): Identity()
#   (586): ParameterModule()
#   (587): ParameterModule()
#   (588): Identity()
#   (589): ParameterModule()
#   (590): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (591): MemoryEfficientSwish()
#   (592): Identity()
#   (593): ParameterModule()
#   (594): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (595): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (596): ParameterModule()
#   (597): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (598): Identity()
#   (599): ParameterModule()
#   (600): ParameterModule()
#   (601): Identity()
#   (602): ParameterModule()
#   (603): ParameterModule()
#   (604): Identity()
#   (605): ParameterModule()
#   (606): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (607): MemoryEfficientSwish()
#   (608): Identity()
#   (609): ParameterModule()
#   (610): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (611): AdaptiveAvgPool2d(output_size=1)
#   (612): Dropout(p=0.5, inplace=False)
#   (613): Linear(in_features=2304, out_features=1000, bias=True)
#   (614): MemoryEfficientSwish()
# ), Sequential(
#   (0): Linear(in_features=1000, out_features=5, bias=True)
# )], add_time=True, silent=False)

# %%
learn.freeze()

# %%
gc.collect()
# Out:
# 100

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-6

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.762637</td>
#       <td>0.533029</td>
#       <td>0.202421</td>
#       <td>12:46</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.640473</td>
#       <td>0.526238</td>
#       <td>0.200403</td>
#       <td>12:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.696014</td>
#       <td>0.521462</td>
#       <td>0.199059</td>
#       <td>13:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.676917</td>
#       <td>0.519995</td>
#       <td>0.197714</td>
#       <td>13:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.648052</td>
#       <td>0.519981</td>
#       <td>0.197041</td>
#       <td>10:22</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1-512-{arch_name}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.load(f'stage-1-512-{arch_name}-{MODEL_NAME}-{DATE}-{UID}')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (13383 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (1487 items)
# x: ImageList
# Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512),Image (3, 512, 512)
# y: CategoryList
# healthy_metal,concrete_cement,irregular_metal,irregular_metal,concrete_cement
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256, model=Sequential(
#   (0): Sequential(
#     (0): EfficientNet(
#       (_conv_stem): Conv2dStaticSamePadding(
#         3, 56, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn0): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_blocks): ModuleList(
#         (0): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             56, 14, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             14, 56, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (1): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (2): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (3): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             192, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 192, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (4): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (5): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (6): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (7): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (8): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (9): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (10): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (11): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (12): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (13): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (14): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (15): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             432, 18, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             18, 432, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (16): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (17): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (18): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (19): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (20): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (21): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (22): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (23): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             864, 36, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             36, 864, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (24): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (25): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (26): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (27): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (28): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (29): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (30): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (31): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1200, 50, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             50, 1200, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (32): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (33): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (34): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (35): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             86, 2064, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (36): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             2064, 86, kernel_size=(1, 1), stride=(1, 1)
# ...
#   (240): Identity()
#   (241): ParameterModule()
#   (242): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (243): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (244): ParameterModule()
#   (245): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (246): Identity()
#   (247): ParameterModule()
#   (248): ParameterModule()
#   (249): Identity()
#   (250): ParameterModule()
#   (251): ParameterModule()
#   (252): Identity()
#   (253): ParameterModule()
#   (254): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (255): MemoryEfficientSwish()
#   (256): Identity()
#   (257): ParameterModule()
#   (258): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (259): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (260): ParameterModule()
#   (261): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (262): Identity()
#   (263): ParameterModule()
#   (264): ParameterModule()
#   (265): Identity()
#   (266): ParameterModule()
#   (267): ParameterModule()
#   (268): Identity()
#   (269): ParameterModule()
#   (270): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (271): MemoryEfficientSwish()
#   (272): Identity()
#   (273): ParameterModule()
#   (274): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (275): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (276): ParameterModule()
#   (277): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (278): Identity()
#   (279): ParameterModule()
#   (280): ParameterModule()
#   (281): Identity()
#   (282): ParameterModule()
#   (283): ParameterModule()
#   (284): Identity()
#   (285): ParameterModule()
#   (286): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (287): MemoryEfficientSwish()
#   (288): Identity()
#   (289): ParameterModule()
#   (290): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (291): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (292): ParameterModule()
#   (293): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (294): Identity()
#   (295): ParameterModule()
#   (296): ParameterModule()
#   (297): Identity()
#   (298): ParameterModule()
#   (299): ParameterModule()
#   (300): Identity()
#   (301): ParameterModule()
#   (302): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (303): MemoryEfficientSwish()
#   (304): Identity()
#   (305): ParameterModule()
#   (306): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (307): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (308): ParameterModule()
#   (309): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (310): Identity()
#   (311): ParameterModule()
#   (312): ParameterModule()
#   (313): Identity()
#   (314): ParameterModule()
#   (315): ParameterModule()
#   (316): Identity()
#   (317): ParameterModule()
#   (318): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (319): MemoryEfficientSwish()
#   (320): Identity()
#   (321): ParameterModule()
#   (322): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (323): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (324): ParameterModule()
#   (325): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (326): Identity()
#   (327): ParameterModule()
#   (328): ParameterModule()
#   (329): Identity()
#   (330): ParameterModule()
#   (331): ParameterModule()
#   (332): Identity()
#   (333): ParameterModule()
#   (334): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (335): MemoryEfficientSwish()
#   (336): Identity()
#   (337): ParameterModule()
#   (338): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (340): ParameterModule()
#   (341): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (342): Identity()
#   (343): ParameterModule()
#   (344): ParameterModule()
#   (345): Identity()
#   (346): ParameterModule()
#   (347): ParameterModule()
#   (348): Identity()
#   (349): ParameterModule()
#   (350): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (351): MemoryEfficientSwish()
#   (352): Identity()
#   (353): ParameterModule()
#   (354): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (355): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (356): ParameterModule()
#   (357): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (358): Identity()
#   (359): ParameterModule()
#   (360): ParameterModule()
#   (361): Identity()
#   (362): ParameterModule()
#   (363): ParameterModule()
#   (364): Identity()
#   (365): ParameterModule()
#   (366): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (367): MemoryEfficientSwish()
#   (368): Identity()
#   (369): ParameterModule()
#   (370): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (371): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (372): ParameterModule()
#   (373): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (374): Identity()
#   (375): ParameterModule()
#   (376): ParameterModule()
#   (377): Identity()
#   (378): ParameterModule()
#   (379): ParameterModule()
#   (380): Identity()
#   (381): ParameterModule()
#   (382): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (383): MemoryEfficientSwish()
#   (384): Identity()
#   (385): ParameterModule()
#   (386): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (387): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (388): ParameterModule()
#   (389): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (390): Identity()
#   (391): ParameterModule()
#   (392): ParameterModule()
#   (393): Identity()
#   (394): ParameterModule()
#   (395): ParameterModule()
#   (396): Identity()
#   (397): ParameterModule()
#   (398): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (399): MemoryEfficientSwish()
#   (400): Identity()
#   (401): ParameterModule()
#   (402): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (403): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (404): ParameterModule()
#   (405): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (406): Identity()
#   (407): ParameterModule()
#   (408): ParameterModule()
#   (409): Identity()
#   (410): ParameterModule()
#   (411): ParameterModule()
#   (412): Identity()
#   (413): ParameterModule()
#   (414): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (415): MemoryEfficientSwish()
#   (416): Identity()
#   (417): ParameterModule()
#   (418): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (419): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (420): ParameterModule()
#   (421): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (422): Identity()
#   (423): ParameterModule()
#   (424): ParameterModule()
#   (425): Identity()
#   (426): ParameterModule()
#   (427): ParameterModule()
#   (428): Identity()
#   (429): ParameterModule()
#   (430): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (431): MemoryEfficientSwish()
#   (432): Identity()
#   (433): ParameterModule()
#   (434): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (435): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (436): ParameterModule()
#   (437): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (438): Identity()
#   (439): ParameterModule()
#   (440): ParameterModule()
#   (441): Identity()
#   (442): ParameterModule()
#   (443): ParameterModule()
#   (444): Identity()
#   (445): ParameterModule()
#   (446): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (447): MemoryEfficientSwish()
#   (448): Identity()
#   (449): ParameterModule()
#   (450): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (451): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (452): ParameterModule()
#   (453): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (454): Identity()
#   (455): ParameterModule()
#   (456): ParameterModule()
#   (457): Identity()
#   (458): ParameterModule()
#   (459): ParameterModule()
#   (460): Identity()
#   (461): ParameterModule()
#   (462): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (463): MemoryEfficientSwish()
#   (464): Identity()
#   (465): ParameterModule()
#   (466): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (467): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (468): ParameterModule()
#   (469): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (470): Identity()
#   (471): ParameterModule()
#   (472): ParameterModule()
#   (473): Identity()
#   (474): ParameterModule()
#   (475): ParameterModule()
#   (476): Identity()
#   (477): ParameterModule()
#   (478): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (479): MemoryEfficientSwish()
#   (480): Identity()
#   (481): ParameterModule()
#   (482): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (483): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (484): ParameterModule()
#   (485): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (486): Identity()
#   (487): ParameterModule()
#   (488): ParameterModule()
#   (489): Identity()
#   (490): ParameterModule()
#   (491): ParameterModule()
#   (492): Identity()
#   (493): ParameterModule()
#   (494): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (495): MemoryEfficientSwish()
#   (496): Identity()
#   (497): ParameterModule()
#   (498): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (499): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (500): ParameterModule()
#   (501): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (502): Identity()
#   (503): ParameterModule()
#   (504): ParameterModule()
#   (505): Identity()
#   (506): ParameterModule()
#   (507): ParameterModule()
#   (508): Identity()
#   (509): ParameterModule()
#   (510): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (511): MemoryEfficientSwish()
#   (512): Identity()
#   (513): ParameterModule()
#   (514): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (515): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (516): ParameterModule()
#   (517): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (518): Identity()
#   (519): ParameterModule()
#   (520): ParameterModule()
#   (521): Identity()
#   (522): ParameterModule()
#   (523): ParameterModule()
#   (524): Identity()
#   (525): ParameterModule()
#   (526): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (527): MemoryEfficientSwish()
#   (528): Identity()
#   (529): ParameterModule()
#   (530): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (531): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (532): ParameterModule()
#   (533): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (534): Identity()
#   (535): ParameterModule()
#   (536): ParameterModule()
#   (537): Identity()
#   (538): ParameterModule()
#   (539): ParameterModule()
#   (540): Identity()
#   (541): ParameterModule()
#   (542): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (543): MemoryEfficientSwish()
#   (544): Identity()
#   (545): ParameterModule()
#   (546): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (547): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (548): ParameterModule()
#   (549): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (550): Identity()
#   (551): ParameterModule()
#   (552): ParameterModule()
#   (553): Identity()
#   (554): ParameterModule()
#   (555): ParameterModule()
#   (556): Identity()
#   (557): ParameterModule()
#   (558): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (559): MemoryEfficientSwish()
#   (560): Identity()
#   (561): ParameterModule()
#   (562): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (563): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (564): ParameterModule()
#   (565): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (566): Identity()
#   (567): ParameterModule()
#   (568): ParameterModule()
#   (569): Identity()
#   (570): ParameterModule()
#   (571): ParameterModule()
#   (572): Identity()
#   (573): ParameterModule()
#   (574): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (575): MemoryEfficientSwish()
#   (576): Identity()
#   (577): ParameterModule()
#   (578): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (579): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (580): ParameterModule()
#   (581): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): Identity()
#   (583): ParameterModule()
#   (584): ParameterModule()
#   (585): Identity()
#   (586): ParameterModule()
#   (587): ParameterModule()
#   (588): Identity()
#   (589): ParameterModule()
#   (590): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (591): MemoryEfficientSwish()
#   (592): Identity()
#   (593): ParameterModule()
#   (594): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (595): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (596): ParameterModule()
#   (597): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (598): Identity()
#   (599): ParameterModule()
#   (600): ParameterModule()
#   (601): Identity()
#   (602): ParameterModule()
#   (603): ParameterModule()
#   (604): Identity()
#   (605): ParameterModule()
#   (606): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (607): MemoryEfficientSwish()
#   (608): Identity()
#   (609): ParameterModule()
#   (610): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (611): AdaptiveAvgPool2d(output_size=1)
#   (612): Dropout(p=0.5, inplace=False)
#   (613): Linear(in_features=2304, out_features=1000, bias=True)
#   (614): MemoryEfficientSwish()
# ), Sequential(
#   (0): Linear(in_features=1000, out_features=5, bias=True)
# )], add_time=True, silent=False)

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
lr=1e-4

# %%
learn.fit_one_cycle(5, slice(3e-6, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.569901</td>
#       <td>0.496969</td>
#       <td>0.182246</td>
#       <td>16:45</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.560658</td>
#       <td>0.487875</td>
#       <td>0.179556</td>
#       <td>16:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.541068</td>
#       <td>0.488430</td>
#       <td>0.176194</td>
#       <td>16:48</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.503098</td>
#       <td>0.482488</td>
#       <td>0.179556</td>
#       <td>16:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.514433</td>
#       <td>0.481837</td>
#       <td>0.179556</td>
#       <td>16:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save(f'stage-2-512-{arch_name}-{MODEL_NAME}-{DATE}-{UID}')

# %% [markdown]
# You won't really know how you're going until you submit to Kaggle, since the leaderboard isn't using the same subset as we have for training. But as a guide, 50th place (out of 938 teams) on the private leaderboard was a score of `0.930`.

# %%
learn=learn.to_fp32()

# %%
learn.export()

# %% [markdown]
# ### inference

# %%
test_images=data_dir/f'test/rotated/clipped/512'
test_dataset=ImageList.from_folder(test_images)

# %%
len(test_dataset)
# Out:
# 1

# %%
test/rotated/clipped/reflect/512/
learn = load_learner(path=data_dir/f'train/rotated/clipped/reflect/512', test=test_dataset)

# %%
#learn = load_learner(path=data_dir/f'train/rotated/clipped/{img_size}', file=f'stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.pkl', test=test_dataset)

# %%
learn.data.loss_func

# %%
type(learn.data)

# %%
type(learn.dl(DatasetType.Test))

# %%
len(learn.dl(DatasetType.Test))

# %% [markdown]
# Get number of items in the Valid dataset (in DeviceDataLoader)

# %%
#assert len(learn.dl(DatasetType.Test).dl)==7325

# %% [markdown]
# Required format:
#
# <pre>
# id	concrete_cement	healthy_metal	incomplete	irregular_metal	other
# 7a4d630a	0.9	0	0	0	0
# 7a4bbbd6	0.9	0	0	0	0
# 7a4ac744	0.9	0	0	0	0
# 7a4881fa	0.9	0	0	0	0
# 7a4aa4a8	0.9	0	0	0	0
# </pre>

# %%
preds,y= learn.get_preds(ds_type=DatasetType.Test)

# %%
labels = np.argmax(preds, 1)

# %%
len(preds)

# %%
preds[0].tolist()

# %%
preds_list=[]
for pred in preds:
    preds_list.append(pred.tolist())

# %%
len(labels)

# %%
learn.data.classes

# %%
data.classes

# %%
test_predictions = [learn.data.classes[int(x)] for x in labels]

# %%
test_predictions[0]

# %%
type(learn.data.test_ds)

# %%
 learn.data.test_ds.x.items

# %%
ids=[]
for item in learn.data.test_ds.x.items:
    base, id = os.path.split(item)
    id = id.split('.tif')[0]
    ids.append(id)

# %%
preds_list[0]

# %%
cols = learn.data.classes.copy()
cols.insert(0,'id')
df = pd.DataFrame(list(zip(ids, preds_list)), 
               columns =['id', 'pred'])

# %%
cols

# %%
df.head()

# %%
pred_df = pd.DataFrame(df['pred'].values.tolist())

# %%
pred_df.insert(loc=0, column='id', value=ids)

# %%
pred_df.columns = cols

# %%
pred_df.head()

# %% [markdown]
# Required format:
#
# <pre>
# id	concrete_cement	healthy_metal	incomplete	irregular_metal	other
# 7a4d630a	0.9	0	0	0	0
# 7a4bbbd6	0.9	0	0	0	0
# 7a4ac744	0.9	0	0	0	0
# 7a4881fa	0.9	0	0	0	0
# 7a4aa4a8	0.9	0	0	0	0
# </pre>

# %%
#pred_df = pd.read_csv(data_dir/f'submissions/stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.csv')

# %%
pred_df.head()

# %%
pred_ids=pred_df['id'].values.tolist()

# %%
df_baseline = pd.read_csv(data_dir/f'submissions/mean_baseline.csv')

# %%
df_baseline.head()

# %%
baseline_ids=df_baseline['id'].values.tolist()

# %%
baseline_ids

# %%
assert set(pred_ids)==set(baseline_ids)

# %% [markdown]
# #### sort by baseline ids

# %%
pred_df['id_cat'] = pd.Categorical(
    pred_df['id'], 
    categories=baseline_ids, 
    ordered=True
)

# %%
pred_df.head()

# %%
pred_df=pred_df.sort_values('id_cat')

# %%
pred_df.head()

# %%
pred_df.drop(columns=['id_cat'],inplace=True)

# %%
pred_df=pred_df.drop_duplicates(subset=['id'])

# %%
pred_df.to_csv(data_dir/f'submissions/stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.csv', index=False)

# %%
### Submission 2: 0.4461

# %%
pred_df=pd.read_csv(data_dir/f'submissions/stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.csv')

# %%
pred_df.drop(columns=['id'],inplace=True)
classes=pred_df.idxmax(axis=1)
pd.value_counts(classes).plot(kind="bar")
