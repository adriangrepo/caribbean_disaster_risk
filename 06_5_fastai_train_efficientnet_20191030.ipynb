# %% [markdown]
# ## Train and Prediction on all data
#
# Using rotated to hz + OpenCv border
#
# Basic default transforms
#
# see:
#
# https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/cnn_archs.ipynb
#
# and
#
# https://github.com/PPPW/deep-learning-random-explore/blob/master/CNN_archs/cnn_archs_more.ipynb
#
# mem use 3GB with bs=32 TODO increase
#
# With warp and bs 64

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from torchvision.models import *
from efficientnet_pytorch import EfficientNet
import pretrainedmodels

# %%
from fastai.vision import *
from fastai.vision.models import *
from fastai.vision.learner import model_meta
import geopandas as gpd
from resizeimage import resizeimage
import datetime
import uuid
from os import listdir
from os.path import isfile, join

# %%
__version__
# Out:
# '1.0.59.dev0'

# %%
m = EfficientNet.from_pretrained('efficientnet-b0')
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
def arch_summary(arch):
    model = arch(False)
    tot = 0
    for i, l in enumerate(model.children()):
        n_layers = len(flatten_model(l))
        tot += n_layers
        print(f'({i}) {l.__class__.__name__:<12}: {n_layers:<4}layers (total: {tot})')

# %%
def get_groups(model, layer_groups):
    group_indices = [len(g) for g in layer_groups]
    curr_i = 0
    group = []
    for layer in model:
        group_indices[curr_i] -= len(flatten_model(layer))
        group.append(layer.__class__.__name__)
        if group_indices[curr_i] == 0:
            curr_i += 1
            print(f'Group {curr_i}:', group)   
            group = []

# %%
arch_summary(lambda _: m)
# Out:
# (0) Conv2dStaticSamePadding: 2   layers (total: 2)
# (1) BatchNorm2d : 1   layers (total: 3)
# (2) ModuleList  : 253 layers (total: 256)
# (3) Conv2dStaticSamePadding: 2   layers (total: 258)
# (4) BatchNorm2d : 1   layers (total: 259)
# (5) AdaptiveAvgPool2d: 1   layers (total: 260)
# (6) Dropout     : 1   layers (total: 261)
# (7) Linear      : 1   layers (total: 262)
# (8) MemoryEfficientSwish: 1   layers (total: 263)

# %%
arch_summary(lambda _: list(m.children())[2])
# Out:
# (0) MBConvBlock : 13  layers (total: 13)
# (1) MBConvBlock : 16  layers (total: 29)
# (2) MBConvBlock : 16  layers (total: 45)
# (3) MBConvBlock : 16  layers (total: 61)
# (4) MBConvBlock : 16  layers (total: 77)
# (5) MBConvBlock : 16  layers (total: 93)
# (6) MBConvBlock : 16  layers (total: 109)
# (7) MBConvBlock : 16  layers (total: 125)
# (8) MBConvBlock : 16  layers (total: 141)
# (9) MBConvBlock : 16  layers (total: 157)
# (10) MBConvBlock : 16  layers (total: 173)
# (11) MBConvBlock : 16  layers (total: 189)
# (12) MBConvBlock : 16  layers (total: 205)
# (13) MBConvBlock : 16  layers (total: 221)
# (14) MBConvBlock : 16  layers (total: 237)
# (15) MBConvBlock : 16  layers (total: 253)

# %%
torch.cuda.set_device(2)
torch.cuda.current_device()
# Out:
# 2

# %%
data_dir = Path('data')
colombia_rural = Path('data/stac/colombia/borde_rural')
colombia_soacha = Path('data/stac/colombia/borde_soacha')

# %%
guatemala_mixco1 = Path('data/stac/guatemala/mixco_1_and_ebenezer')
guatemala_mixco3 = Path('data/stac/guatemala/mixco_3')

# %%
st_lucia_castries = Path('data/stac/st_lucia/castries')
st_lucia_dennery = Path('data/stac/st_lucia/dennery')
st_lucia_gros_islet = Path('data/stac/st_lucia/gros_islet')

# %%
COUNTRY='colombia'
REGION='borde_rural'
DATASET = f'{COUNTRY}_{REGION}'
DATASET_PATH=colombia_rural
path=data_dir/f'{COUNTRY}_{REGION}/cropped/'
TRAIN_JSON = f'train-{REGION}.geojson'
TEST_JSON = f'test-{REGION}.geojson'

# %%
RETRAIN = True
RESIZE_IMAGES = True

# %%
MODEL_NAME='efficientnet'

# %%
NB_NUM='06_5'

# %%
DATE = datetime.datetime.today().strftime('%Y%m%d')
UID=str(uuid.uuid4())[:8]
print(f'UID: {UID}, DATE: {DATE}')
# Out:
# UID: fa0754ea, DATE: 20191030

# %%
#DATE = '20191026'
#UID = '1964891c'

# %%
SUB_NUM='6'

# %%
img_size=256
bs=64

# %%
train_images=data_dir/f'train/rotated/clipped/{img_size}'
test_images=data_dir/f'test/rotated/clipped/{img_size}'

# %%
test_names = get_image_files(test_images)

# %%
assert len(test_names)==7325

# %%
df_all=pd.read_csv(data_dir/'df_train_all.csv')

# %%
df_all.tail()
# Out:
#              id  roof_material  verified   country      region
# 22548  7a22ddec  healthy_metal     False  st_lucia  gros_islet
# 22549  7a2f73ea  healthy_metal     False  st_lucia  gros_islet
# 22550  7a34ffa4  healthy_metal     False  st_lucia  gros_islet
# 22551  7a41560a  healthy_metal     False  st_lucia  gros_islet
# 22552  7a283ad0  healthy_metal     False  st_lucia  gros_islet

# %%
df_test=pd.read_csv(data_dir/'df_test_all.csv')

# %%
df_test.tail()
# Out:
#             id   country   region
# 7320  7a4f3ff4  st_lucia  dennery
# 7321  7a4fc578  st_lucia  dennery
# 7322  7a4ac7b2  st_lucia  dennery
# 7323  7a47e25e  st_lucia  dennery
# 7324  7a4e3f78  st_lucia  dennery

# %%
assert len(df_test)==7325

# %%
df_all.loc[df_all['id'] == '7a204ec4']
# Out:
#              id    roof_material  verified    country                region
# 12960  7a204ec4  irregular_metal      True  guatemala  mixco_1_and_ebenezer

# %%
len(df_all)
# Out:
# 22553

# %% [markdown]
# To put this in a `DataBunch` while using the [data block API](https://docs.fast.ai/data_block.html), we then need to using `ImageList` (and not `ImageDataBunch`). This will make sure the model created has the proper loss function to deal with the multiple classes.

# %%
tfms = get_transforms(flip_vert=True, max_lighting=0.15, max_zoom=1.1, max_warp=0.05)

# %% [markdown]
# ### setup dataset

# %%
np.random.seed(42)
dep_var='roof_material'
src = (ImageList.from_df(path=train_images, df=df_all, cols='id', suffix='.tif')
       .split_by_rand_pct(0.2)
      .label_from_df(cols=dep_var)
      .add_test_folder(test_images))

# %%
data = (src.transform(tfms, size=img_size)
        .databunch(bs=bs).normalize(imagenet_stats))

# %%
#to check what params object has
#dir(data)

# %%
data.label_list
# Out:
# LabelLists;
#
# Train: LabelList (18043 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (4510 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# irregular_metal,healthy_metal,healthy_metal,irregular_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256

# %%
data.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %% [markdown]
# `show_batch` still works, and show us the different labels separated by `;`.

# %%
data.show_batch(rows=3, figsize=(12,9))

# %%
def get_groups(model, layer_groups):
    group_indices = [len(g) for g in layer_groups]
    curr_i = 0
    group = []
    for layer in model:
        group_indices[curr_i] -= len(flatten_model(layer))
        group.append(layer.__class__.__name__)
        if group_indices[curr_i] == 0:
            curr_i += 1
            print(f'Group {curr_i}:', group)   
            group = []

# %% [markdown]
# ### Model

# %%
# "pretrained" is hardcoded to adapt to the PyTorch model function
def efficient_net_b0(pretrained=True):
    model = EfficientNet.from_pretrained('efficientnet-b0')
    return nn.Sequential(model)

# %%
model_meta[efficient_net_b0] =  { 'cut': noop, 
                               'split': lambda m: (list(m[0][0].children())[2][7], m[1]) }

# %%
list(efficient_net_b0()[0].children())
# Out:
# Loaded pretrained weights for efficientnet-b0
# [Conv2dStaticSamePadding(
#    3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#    (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#  ),
#  BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True),
#  ModuleList(
#    (0): MBConvBlock(
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        32, 8, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        8, 32, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (1): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#        (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        96, 4, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        4, 96, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (2): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        144, 6, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        6, 144, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (3): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        144, 6, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        6, 144, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (4): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (5): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#        (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        240, 10, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        10, 240, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (6): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        480, 20, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        20, 480, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (7): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        480, 20, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        20, 480, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (8): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        480, 20, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        20, 480, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (9): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        672, 28, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        28, 672, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (10): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        672, 28, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        28, 672, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (11): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        672, 28, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        28, 672, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (12): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1152, 48, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        48, 1152, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (13): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1152, 48, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        48, 1152, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (14): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#        (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1152, 48, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        48, 1152, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#    (15): MBConvBlock(
#      (_expand_conv): Conv2dStaticSamePadding(
#        192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_depthwise_conv): Conv2dStaticSamePadding(
#        1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#        (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#      )
#      (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_se_reduce): Conv2dStaticSamePadding(
#        1152, 48, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_se_expand): Conv2dStaticSamePadding(
#        48, 1152, kernel_size=(1, 1), stride=(1, 1)
#        (static_padding): Identity()
#      )
#      (_project_conv): Conv2dStaticSamePadding(
#        1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#        (static_padding): Identity()
#      )
#      (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#      (_swish): MemoryEfficientSwish()
#    )
#  ),
#  Conv2dStaticSamePadding(
#    320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#    (static_padding): Identity()
#  ),
#  BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True),
#  AdaptiveAvgPool2d(output_size=1),
#  Dropout(p=0.2, inplace=False),
#  Linear(in_features=1280, out_features=1000, bias=True),
#  MemoryEfficientSwish()]

# %%
output_size = list(efficient_net_b0()[0].children())[-2].out_features
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
output_size
# Out:
# 1000

# %%
custom_head = nn.Linear(output_size, data.c)

# %%
arch = efficient_net_b0
arch_name = 'efficient_net_b0'

# %%
learn = cnn_learner(data, arch, custom_head = custom_head, metrics=error_rate, bn_final=True).to_fp16()
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
get_groups(nn.Sequential(*list(learn.model[0][0].children())[:2], 
                         *list(learn.model[0][0].children())[2],
                         *list(learn.model[0][0].children())[3:],
                         learn.model[1]), 
           learn.layer_groups)
# Out:
# Group 1: ['Conv2dStaticSamePadding', 'BatchNorm2d', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock']
# Group 2: ['MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'MBConvBlock', 'Conv2dStaticSamePadding', 'BatchNorm2d', 'AdaptiveAvgPool2d', 'Dropout', 'Linear', 'MemoryEfficientSwish']
# Group 3: ['Linear']

# %%
#learn.model = torch.nn.DataParallel(learn.model, device_ids=[0, 1, 2])

# %% [markdown]
# We use the LR Finder to pick a good learning rate.

# %% [markdown]
# ### train model

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %% [markdown]
# Then we can fit the head of our network.

# %%
lr = 5e-3

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.797197</td>
#       <td>0.685558</td>
#       <td>0.250333</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.728562</td>
#       <td>0.685669</td>
#       <td>0.233481</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.656235</td>
#       <td>0.613815</td>
#       <td>0.217295</td>
#       <td>01:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.568919</td>
#       <td>0.564382</td>
#       <td>0.195565</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.546447</td>
#       <td>0.549731</td>
#       <td>0.196452</td>
#       <td>01:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.562043</td>
#       <td>0.602343</td>
#       <td>0.205543</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.636011</td>
#       <td>0.628016</td>
#       <td>0.221729</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.612695</td>
#       <td>0.562571</td>
#       <td>0.194900</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.538537</td>
#       <td>0.526366</td>
#       <td>0.181596</td>
#       <td>01:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.493894</td>
#       <td>0.512850</td>
#       <td>0.180044</td>
#       <td>01:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.512495</td>
#       <td>0.560578</td>
#       <td>0.194900</td>
#       <td>01:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.611634</td>
#       <td>0.575836</td>
#       <td>0.201552</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.538178</td>
#       <td>0.542497</td>
#       <td>0.190022</td>
#       <td>01:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.481708</td>
#       <td>0.505978</td>
#       <td>0.178936</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.458191</td>
#       <td>0.490952</td>
#       <td>0.172949</td>
#       <td>01:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-1c-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %% [markdown]
# #### Load model

# %%
learn.load(f'stage-1c-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (18043 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (4510 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# irregular_metal,healthy_metal,healthy_metal,irregular_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256, model=Sequential(
#   (0): Sequential(
#     (0): EfficientNet(
#       (_conv_stem): Conv2dStaticSamePadding(
#         3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_blocks): ModuleList(
#         (0): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (1): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             96, 4, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             4, 96, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (2): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             144, 6, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             6, 144, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (3): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             144, 6, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             6, 144, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (4): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (5): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (6): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             480, 20, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             20, 480, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (7): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             480, 20, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             20, 480, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (8): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             480, 20, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             20, 480, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (9): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             672, 28, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             28, 672, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (10): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             672, 28, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             28, 672, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (11): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             672, 28, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             28, 672, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (12): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (13): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (14): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (15): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#       )
#       (_conv_head): Conv2dStaticSamePadding(
#         320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#       (_dropout): Dropout(p=0.2, inplace=False)
#       (_fc): Linear(in_features=1280, out_features=1000, bias=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (1): Linear(in_features=1000, out_features=5, bias=True)
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function error_rate at 0x7fd4a0364170>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('data/train/rotated/clipped/256'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[MixedPrecision
# learn: ...
# loss_scale: 8192.0
# max_noskip: 1000
# dynamic: True
# clip: None
# flat_master: False
# max_scale: 16777216
# loss_fp32: True], layer_groups=[Sequential(
#   (0): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (1): ParameterModule()
#   (2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): Identity()
#   (17): ParameterModule()
#   (18): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (20): ParameterModule()
#   (21): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): ParameterModule()
#   (28): Identity()
#   (29): ParameterModule()
#   (30): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (31): MemoryEfficientSwish()
#   (32): Identity()
#   (33): ParameterModule()
#   (34): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (36): ParameterModule()
#   (37): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): ParameterModule()
#   (44): Identity()
#   (45): ParameterModule()
#   (46): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (47): MemoryEfficientSwish()
#   (48): Identity()
#   (49): ParameterModule()
#   (50): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (52): ParameterModule()
#   (53): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): ParameterModule()
#   (60): Identity()
#   (61): ParameterModule()
#   (62): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (63): MemoryEfficientSwish()
#   (64): Identity()
#   (65): ParameterModule()
#   (66): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (68): ParameterModule()
#   (69): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): ParameterModule()
#   (76): Identity()
#   (77): ParameterModule()
#   (78): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (79): MemoryEfficientSwish()
#   (80): Identity()
#   (81): ParameterModule()
#   (82): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (84): ParameterModule()
#   (85): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): ParameterModule()
#   (92): Identity()
#   (93): ParameterModule()
#   (94): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (95): MemoryEfficientSwish()
#   (96): Identity()
#   (97): ParameterModule()
#   (98): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (100): ParameterModule()
#   (101): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): ParameterModule()
#   (108): Identity()
#   (109): ParameterModule()
#   (110): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (111): MemoryEfficientSwish()
# ), Sequential(
#   (0): Identity()
#   (1): ParameterModule()
#   (2): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): Identity()
#   (17): ParameterModule()
#   (18): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (20): ParameterModule()
#   (21): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): ParameterModule()
#   (28): Identity()
#   (29): ParameterModule()
#   (30): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (31): MemoryEfficientSwish()
#   (32): Identity()
#   (33): ParameterModule()
#   (34): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (36): ParameterModule()
#   (37): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): ParameterModule()
#   (44): Identity()
#   (45): ParameterModule()
#   (46): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (47): MemoryEfficientSwish()
#   (48): Identity()
#   (49): ParameterModule()
#   (50): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (52): ParameterModule()
#   (53): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): ParameterModule()
#   (60): Identity()
#   (61): ParameterModule()
#   (62): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (63): MemoryEfficientSwish()
#   (64): Identity()
#   (65): ParameterModule()
#   (66): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (68): ParameterModule()
#   (69): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): ParameterModule()
#   (76): Identity()
#   (77): ParameterModule()
#   (78): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (79): MemoryEfficientSwish()
#   (80): Identity()
#   (81): ParameterModule()
#   (82): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (84): ParameterModule()
#   (85): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): ParameterModule()
#   (92): Identity()
#   (93): ParameterModule()
#   (94): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (95): MemoryEfficientSwish()
#   (96): Identity()
#   (97): ParameterModule()
#   (98): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (100): ParameterModule()
#   (101): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): ParameterModule()
#   (108): Identity()
#   (109): ParameterModule()
#   (110): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (111): MemoryEfficientSwish()
#   (112): Identity()
#   (113): ParameterModule()
#   (114): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (115): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (116): ParameterModule()
#   (117): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (118): Identity()
#   (119): ParameterModule()
#   (120): ParameterModule()
#   (121): Identity()
#   (122): ParameterModule()
#   (123): ParameterModule()
#   (124): Identity()
#   (125): ParameterModule()
#   (126): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (127): MemoryEfficientSwish()
#   (128): Identity()
#   (129): ParameterModule()
#   (130): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (131): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (132): ParameterModule()
#   (133): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (134): Identity()
#   (135): ParameterModule()
#   (136): ParameterModule()
#   (137): Identity()
#   (138): ParameterModule()
#   (139): ParameterModule()
#   (140): Identity()
#   (141): ParameterModule()
#   (142): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (143): MemoryEfficientSwish()
#   (144): Identity()
#   (145): ParameterModule()
#   (146): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (147): AdaptiveAvgPool2d(output_size=1)
#   (148): Dropout(p=0.2, inplace=False)
#   (149): Linear(in_features=1280, out_features=1000, bias=True)
#   (150): MemoryEfficientSwish()
# ), Sequential(
#   (0): Linear(in_features=1000, out_features=5, bias=True)
# )], add_time=True, silent=False)

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.most_confused(min_val=2)
# Out:
# [('irregular_metal', 'healthy_metal', 275),
#  ('healthy_metal', 'irregular_metal', 170),
#  ('incomplete', 'irregular_metal', 75),
#  ('concrete_cement', 'healthy_metal', 49),
#  ('other', 'healthy_metal', 44),
#  ('healthy_metal', 'concrete_cement', 26),
#  ('irregular_metal', 'incomplete', 26),
#  ('concrete_cement', 'incomplete', 22),
#  ('incomplete', 'healthy_metal', 21),
#  ('irregular_metal', 'concrete_cement', 18),
#  ('concrete_cement', 'irregular_metal', 14),
#  ('incomplete', 'concrete_cement', 12),
#  ('healthy_metal', 'incomplete', 11),
#  ('other', 'irregular_metal', 7),
#  ('healthy_metal', 'other', 6),
#  ('other', 'concrete_cement', 2)]

# %%
interp.plot_confusion_matrix(figsize=(10,10), dpi=60)

# %% [markdown]
# ### Re-train

# %%
learn.unfreeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.466111</td>
#       <td>0.494541</td>
#       <td>0.176275</td>
#       <td>01:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.465862</td>
#       <td>0.464506</td>
#       <td>0.161863</td>
#       <td>01:29</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.394449</td>
#       <td>0.433086</td>
#       <td>0.150111</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.379910</td>
#       <td>0.419631</td>
#       <td>0.144568</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.340148</td>
#       <td>0.418652</td>
#       <td>0.144124</td>
#       <td>01:33</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save(f'stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.load(f'stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (18043 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# concrete_cement,irregular_metal,healthy_metal,healthy_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Valid: LabelList (4510 items)
# x: ImageList
# Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256),Image (3, 256, 256)
# y: CategoryList
# irregular_metal,healthy_metal,healthy_metal,irregular_metal,healthy_metal
# Path: data/train/rotated/clipped/256;
#
# Test: LabelList (0 items)
# x: ImageList
#
# y: EmptyLabelList
#
# Path: data/train/rotated/clipped/256, model=Sequential(
#   (0): Sequential(
#     (0): EfficientNet(
#       (_conv_stem): Conv2dStaticSamePadding(
#         3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn0): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_blocks): ModuleList(
#         (0): MBConvBlock(
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             32, 32, kernel_size=(3, 3), stride=[1, 1], groups=32, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             32, 8, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             8, 32, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (1): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             96, 96, kernel_size=(3, 3), stride=[2, 2], groups=96, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             96, 4, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             4, 96, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (2): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             144, 144, kernel_size=(3, 3), stride=(1, 1), groups=144, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             144, 6, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             6, 144, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (3): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             144, 144, kernel_size=(5, 5), stride=[2, 2], groups=144, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             144, 6, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             6, 144, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (4): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(5, 5), stride=(1, 1), groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (5): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             240, 240, kernel_size=(3, 3), stride=[2, 2], groups=240, bias=False
#             (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             240, 10, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             10, 240, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (6): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             480, 20, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             20, 480, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (7): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             480, 480, kernel_size=(3, 3), stride=(1, 1), groups=480, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             480, 20, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             20, 480, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (8): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             480, 480, kernel_size=(5, 5), stride=[1, 1], groups=480, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             480, 20, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             20, 480, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (9): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             672, 28, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             28, 672, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (10): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             672, 672, kernel_size=(5, 5), stride=(1, 1), groups=672, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             672, 28, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             28, 672, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (11): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             672, 672, kernel_size=(5, 5), stride=[2, 2], groups=672, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             672, 28, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             28, 672, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (12): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (13): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (14): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(5, 5), stride=(1, 1), groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#         (15): MBConvBlock(
#           (_expand_conv): Conv2dStaticSamePadding(
#             192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn0): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_depthwise_conv): Conv2dStaticSamePadding(
#             1152, 1152, kernel_size=(3, 3), stride=[1, 1], groups=1152, bias=False
#             (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#           )
#           (_bn1): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_se_reduce): Conv2dStaticSamePadding(
#             1152, 48, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_se_expand): Conv2dStaticSamePadding(
#             48, 1152, kernel_size=(1, 1), stride=(1, 1)
#             (static_padding): Identity()
#           )
#           (_project_conv): Conv2dStaticSamePadding(
#             1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (static_padding): Identity()
#           )
#           (_bn2): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#           (_swish): MemoryEfficientSwish()
#         )
#       )
#       (_conv_head): Conv2dStaticSamePadding(
#         320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn1): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_avg_pooling): AdaptiveAvgPool2d(output_size=1)
#       (_dropout): Dropout(p=0.2, inplace=False)
#       (_fc): Linear(in_features=1280, out_features=1000, bias=True)
#       (_swish): MemoryEfficientSwish()
#     )
#   )
#   (1): Linear(in_features=1000, out_features=5, bias=True)
# ), opt_func=functools.partial(<class 'torch.optim.adam.Adam'>, betas=(0.9, 0.99)), loss_func=FlattenedLoss of CrossEntropyLoss(), metrics=[<function error_rate at 0x7fd4a0364170>], true_wd=True, bn_wd=True, wd=0.01, train_bn=True, path=PosixPath('data/train/rotated/clipped/256'), model_dir='models', callback_fns=[functools.partial(<class 'fastai.basic_train.Recorder'>, add_time=True, silent=False)], callbacks=[MixedPrecision
# learn: ...
# loss_scale: 2048.0
# max_noskip: 1000
# dynamic: True
# clip: None
# flat_master: False
# max_scale: 16777216
# loss_fp32: True], layer_groups=[Sequential(
#   (0): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (1): ParameterModule()
#   (2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(16, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): Identity()
#   (17): ParameterModule()
#   (18): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (20): ParameterModule()
#   (21): BatchNorm2d(96, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): ParameterModule()
#   (28): Identity()
#   (29): ParameterModule()
#   (30): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (31): MemoryEfficientSwish()
#   (32): Identity()
#   (33): ParameterModule()
#   (34): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (36): ParameterModule()
#   (37): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): ParameterModule()
#   (44): Identity()
#   (45): ParameterModule()
#   (46): BatchNorm2d(24, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (47): MemoryEfficientSwish()
#   (48): Identity()
#   (49): ParameterModule()
#   (50): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (52): ParameterModule()
#   (53): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): ParameterModule()
#   (60): Identity()
#   (61): ParameterModule()
#   (62): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (63): MemoryEfficientSwish()
#   (64): Identity()
#   (65): ParameterModule()
#   (66): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (68): ParameterModule()
#   (69): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): ParameterModule()
#   (76): Identity()
#   (77): ParameterModule()
#   (78): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (79): MemoryEfficientSwish()
#   (80): Identity()
#   (81): ParameterModule()
#   (82): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   (84): ParameterModule()
#   (85): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): ParameterModule()
#   (92): Identity()
#   (93): ParameterModule()
#   (94): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (95): MemoryEfficientSwish()
#   (96): Identity()
#   (97): ParameterModule()
#   (98): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (100): ParameterModule()
#   (101): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): ParameterModule()
#   (108): Identity()
#   (109): ParameterModule()
#   (110): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (111): MemoryEfficientSwish()
# ), Sequential(
#   (0): Identity()
#   (1): ParameterModule()
#   (2): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (3): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (4): ParameterModule()
#   (5): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (6): Identity()
#   (7): ParameterModule()
#   (8): ParameterModule()
#   (9): Identity()
#   (10): ParameterModule()
#   (11): ParameterModule()
#   (12): Identity()
#   (13): ParameterModule()
#   (14): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (15): MemoryEfficientSwish()
#   (16): Identity()
#   (17): ParameterModule()
#   (18): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (19): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (20): ParameterModule()
#   (21): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (22): Identity()
#   (23): ParameterModule()
#   (24): ParameterModule()
#   (25): Identity()
#   (26): ParameterModule()
#   (27): ParameterModule()
#   (28): Identity()
#   (29): ParameterModule()
#   (30): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (31): MemoryEfficientSwish()
#   (32): Identity()
#   (33): ParameterModule()
#   (34): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (35): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (36): ParameterModule()
#   (37): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (38): Identity()
#   (39): ParameterModule()
#   (40): ParameterModule()
#   (41): Identity()
#   (42): ParameterModule()
#   (43): ParameterModule()
#   (44): Identity()
#   (45): ParameterModule()
#   (46): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (47): MemoryEfficientSwish()
#   (48): Identity()
#   (49): ParameterModule()
#   (50): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (51): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (52): ParameterModule()
#   (53): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (54): Identity()
#   (55): ParameterModule()
#   (56): ParameterModule()
#   (57): Identity()
#   (58): ParameterModule()
#   (59): ParameterModule()
#   (60): Identity()
#   (61): ParameterModule()
#   (62): BatchNorm2d(112, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (63): MemoryEfficientSwish()
#   (64): Identity()
#   (65): ParameterModule()
#   (66): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (67): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (68): ParameterModule()
#   (69): BatchNorm2d(672, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (70): Identity()
#   (71): ParameterModule()
#   (72): ParameterModule()
#   (73): Identity()
#   (74): ParameterModule()
#   (75): ParameterModule()
#   (76): Identity()
#   (77): ParameterModule()
#   (78): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (79): MemoryEfficientSwish()
#   (80): Identity()
#   (81): ParameterModule()
#   (82): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (83): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (84): ParameterModule()
#   (85): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (86): Identity()
#   (87): ParameterModule()
#   (88): ParameterModule()
#   (89): Identity()
#   (90): ParameterModule()
#   (91): ParameterModule()
#   (92): Identity()
#   (93): ParameterModule()
#   (94): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (95): MemoryEfficientSwish()
#   (96): Identity()
#   (97): ParameterModule()
#   (98): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (99): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (100): ParameterModule()
#   (101): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (102): Identity()
#   (103): ParameterModule()
#   (104): ParameterModule()
#   (105): Identity()
#   (106): ParameterModule()
#   (107): ParameterModule()
#   (108): Identity()
#   (109): ParameterModule()
#   (110): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (111): MemoryEfficientSwish()
#   (112): Identity()
#   (113): ParameterModule()
#   (114): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (115): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (116): ParameterModule()
#   (117): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (118): Identity()
#   (119): ParameterModule()
#   (120): ParameterModule()
#   (121): Identity()
#   (122): ParameterModule()
#   (123): ParameterModule()
#   (124): Identity()
#   (125): ParameterModule()
#   (126): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (127): MemoryEfficientSwish()
#   (128): Identity()
#   (129): ParameterModule()
#   (130): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (131): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (132): ParameterModule()
#   (133): BatchNorm2d(1152, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (134): Identity()
#   (135): ParameterModule()
#   (136): ParameterModule()
#   (137): Identity()
#   (138): ParameterModule()
#   (139): ParameterModule()
#   (140): Identity()
#   (141): ParameterModule()
#   (142): BatchNorm2d(320, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (143): MemoryEfficientSwish()
#   (144): Identity()
#   (145): ParameterModule()
#   (146): BatchNorm2d(1280, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (147): AdaptiveAvgPool2d(output_size=1)
#   (148): Dropout(p=0.2, inplace=False)
#   (149): Linear(in_features=1280, out_features=1000, bias=True)
#   (150): MemoryEfficientSwish()
# ), Sequential(
#   (0): Linear(in_features=1000, out_features=5, bias=True)
# )], add_time=True, silent=False)

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.347412</td>
#       <td>0.431284</td>
#       <td>0.151885</td>
#       <td>01:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.376541</td>
#       <td>0.433850</td>
#       <td>0.154545</td>
#       <td>01:34</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.317196</td>
#       <td>0.429943</td>
#       <td>0.151885</td>
#       <td>01:33</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.286507</td>
#       <td>0.427754</td>
#       <td>0.145233</td>
#       <td>01:32</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.268658</td>
#       <td>0.421398</td>
#       <td>0.144346</td>
#       <td>01:32</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save(f'stage-2b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn = learn.to_fp32()

# %%
learn.export(f'stage-2b-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.pkl')

# %%
learn.export()

# %% [markdown]
# ### 20191030 up to here, TOTO inference

# %% [markdown]
# ### Larger size images

# %%
data = (src.transform(tfms, size=256)
        .databunch().normalize(imagenet_stats))

learn.data = data
data.train_ds[0][0].shape
# Out:
# torch.Size([3, 512, 512])

# %%
learn.freeze()

# %%
learn.lr_find()
learn.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-47-c7a9c29f9dd1> in <module>
# ----> 1 learn.lr_find()
#       2 learn.recorder.plot()
#
# /mnt/963GB/Data/Python/Code/comps/driven_data/caribbean_disaster_risk/fastai/train.py in lr_find(learn, start_lr, end_lr, num_it, stop_div, wd)
#      39     cb = LRFinder(learn, start_lr, end_lr, num_it, stop_div)
#      40     epochs = int(np.ceil(num_it/len(learn.data.train_dl)))
# ---> 41     learn.fit(epochs, start_lr, callbacks=[cb], wd=wd)
#      42
#      43 def to_fp16(learn:Learner, loss_scale:float=None, max_noskip:int=1000, dynamic:bool=True, clip:float=None,
#
# /mnt/963GB/Data/Python/Code/comps/driven_data/caribbean_disaster_risk/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     199         else: self.opt.lr,self.opt.wd = lr,wd
#     200         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 201         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     202
#     203     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# /mnt/963GB/Data/Python/Code/comps/driven_data/caribbean_disaster_risk/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#     100             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     101                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 102                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     103                 if cb_handler.on_batch_end(loss): break
#     104
#
# /mnt/963GB/Data/Python/Code/comps/driven_data/caribbean_disaster_risk/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      24     if not is_listy(xb): xb = [xb]
#      25     if not is_listy(yb): yb = [yb]
# ---> 26     out = model(*xb)
#      27     out = cb_handler.on_loss_begin(out)
#      28
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torchvision/models/resnet.py in forward(self, x)
#     104         out = self.relu(out)
#     105
# --> 106         out = self.conv3(out)
#     107         out = self.bn3(out)
#     108
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     341
#     342     def forward(self, input):
# --> 343         return self.conv2d_forward(input, self.weight)
#     344
#     345 class Conv3d(_ConvNd):
#
# ~/miniconda3/envs/fastai-dev/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     338                             _pair(0), self.dilation, self.groups)
#     339         return F.conv2d(input, weight, self.bias, self.stride,
# --> 340                         self.padding, self.dilation, self.groups)
#     341
#     342     def forward(self, input):
#
# RuntimeError: CUDA out of memory. Tried to allocate 1024.00 MiB (GPU 0; 10.73 GiB total capacity; 8.32 GiB already allocated; 940.06 MiB free; 621.31 MiB cached)

# %%
lr=1e-2/2

# %%
learn.fit_one_cycle(5, slice(lr))
# Out:
# Total time: 09:01 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.087761</th>
#     <th>0.085013</th>
#     <th>0.958006</th>
#     <th>0.926066</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.087641</th>
#     <th>0.083732</th>
#     <th>0.958260</th>
#     <th>0.927459</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.084250</th>
#     <th>0.082856</th>
#     <th>0.958485</th>
#     <th>0.928200</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.082347</th>
#     <th>0.081470</th>
#     <th>0.960091</th>
#     <th>0.929166</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.078463</th>
#     <th>0.080984</th>
#     <th>0.959249</th>
#     <th>0.930089</th>
#   </tr>
# </table>

# %%
learn.save(f'stage-1-256-{arch_name}-{MODEL_NAME}-{DATE}-{UID}')

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(5, slice(1e-5, lr/5))
# Out:
# Total time: 11:25 <p><table style='width:375px; margin-bottom:10px'>
#   <tr>
#     <th>epoch</th>
#     <th>train_loss</th>
#     <th>valid_loss</th>
#     <th>accuracy_thresh</th>
#     <th>fbeta</th>
#   </tr>
#   <tr>
#     <th>1</th>
#     <th>0.082938</th>
#     <th>0.083548</th>
#     <th>0.957846</th>
#     <th>0.927756</th>
#   </tr>
#   <tr>
#     <th>2</th>
#     <th>0.086312</th>
#     <th>0.084802</th>
#     <th>0.958718</th>
#     <th>0.925416</th>
#   </tr>
#   <tr>
#     <th>3</th>
#     <th>0.084824</th>
#     <th>0.082339</th>
#     <th>0.959975</th>
#     <th>0.930054</th>
#   </tr>
#   <tr>
#     <th>4</th>
#     <th>0.078784</th>
#     <th>0.081425</th>
#     <th>0.959983</th>
#     <th>0.929634</th>
#   </tr>
#   <tr>
#     <th>5</th>
#     <th>0.074530</th>
#     <th>0.080791</th>
#     <th>0.960426</th>
#     <th>0.931257</th>
#   </tr>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save(f'stage-2-256-{arch_name}-{MODEL_NAME}-{DATE}-{UID})

# %% [markdown]
# You won't really know how you're going until you submit to Kaggle, since the leaderboard isn't using the same subset as we have for training. But as a guide, 50th place (out of 938 teams) on the private leaderboard was a score of `0.930`.

# %%
learn.export()

# %% [markdown]
# ### inference

# %%
#test_images=data_dir/f'test/rotated/clipped/{img_size}'
test_dataset=ImageList.from_folder(test_images)

# %%
len(test_dataset)
# Out:
# 15325

# %%
learn = load_learner(path=data_dir/f'train/rotated/clipped/{img_size}', test=test_dataset)

# %%
#learn = load_learner(path=data_dir/f'train/rotated/clipped/{img_size}', file=f'stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.pkl', test=test_dataset)

# %%
learn.data.loss_func
# Out:
# FlattenedLoss of CrossEntropyLoss()

# %%
type(learn.data)
# Out:
# fastai.vision.data.ImageDataBunch

# %%
type(learn.dl(DatasetType.Test))
# Out:
# fastai.basic_data.DeviceDataLoader

# %%
len(learn.dl(DatasetType.Test))
# Out:
# 115

# %% [markdown]
# Get number of items in the Valid dataset (in DeviceDataLoader)

# %%
#assert len(learn.dl(DatasetType.Test).dl)==7325

# %% [markdown]
# Required format:
#
# <pre>
# id	concrete_cement	healthy_metal	incomplete	irregular_metal	other
# 7a4d630a	0.9	0	0	0	0
# 7a4bbbd6	0.9	0	0	0	0
# 7a4ac744	0.9	0	0	0	0
# 7a4881fa	0.9	0	0	0	0
# 7a4aa4a8	0.9	0	0	0	0
# </pre>

# %%
preds,y= learn.get_preds(ds_type=DatasetType.Test)

# %%
labels = np.argmax(preds, 1)

# %%
len(preds)
# Out:
# 7325

# %%
preds[0].tolist()
# Out:
# [0.03346812352538109,
#  0.9584664702415466,
#  0.0006572084967046976,
#  0.006149182096123695,
#  0.001259048469364643]

# %%
preds_list=[]
for pred in preds:
    preds_list.append(pred.tolist())

# %%
len(labels)
# Out:
# 7325

# %%
learn.data.classes
# Out:
# ['concrete_cement', 'healthy_metal', 'incomplete', 'irregular_metal', 'other']

# %%
data.classes
# Out:
# ['concrete_cement', 'healthy_metal', 'incomplete', 'irregular_metal', 'other']

# %%
test_predictions = [learn.data.classes[int(x)] for x in labels]

# %%
test_predictions[0]
# Out:
# 'healthy_metal'

# %%
type(learn.data.test_ds)
# Out:
# fastai.data_block.LabelList

# %%
 learn.data.test_ds.x.items
# Out:
# array([PosixPath('data/test/rotated/clipped/256/7a4d9168.tif'),
#        PosixPath('data/test/rotated/clipped/256/7a4ae922.tif'),
#        PosixPath('data/test/rotated/clipped/256/7a48ca98.tif'),
#        PosixPath('data/test/rotated/clipped/256/7a49c614.tif'), ...,
#        PosixPath('data/test/rotated/clipped/256/7a486800.tif'),
#        PosixPath('data/test/rotated/clipped/256/7a4c49fc.tif'),
#        PosixPath('data/test/rotated/clipped/256/7a501f50.tif'),
#        PosixPath('data/test/rotated/clipped/256/7a4d27b4.tif')], dtype=object)

# %%
ids=[]
for item in learn.data.test_ds.x.items:
    base, id = os.path.split(item)
    id = id.split('.tif')[0]
    ids.append(id)

# %%
preds_list[0]
# Out:
# [0.03346812352538109,
#  0.9584664702415466,
#  0.0006572084967046976,
#  0.006149182096123695,
#  0.001259048469364643]

# %%
cols = learn.data.classes.copy()
cols.insert(0,'id')
df = pd.DataFrame(list(zip(ids, preds_list)), 
               columns =['id', 'pred'])

# %%
cols
# Out:
# ['id',
#  'concrete_cement',
#  'healthy_metal',
#  'incomplete',
#  'irregular_metal',
#  'other']

# %%
df.head()
# Out:
#          id                                               pred
# 0  7a4d9168  [0.03346812352538109, 0.9584664702415466, 0.00...
# 1  7a4ae922  [0.0044168452732264996, 0.8947269320487976, 0....
# 2  7a48ca98  [0.003338959999382496, 0.23377253115177155, 0....
# 3  7a49c614  [0.0004943751264363527, 0.8595386147499084, 0....
# 4  7a4dd4f2  [0.0005148547934368253, 0.9120095372200012, 0....

# %%
pred_df = pd.DataFrame(df['pred'].values.tolist())

# %%
pred_df.insert(loc=0, column='id', value=ids)

# %%
pred_df.columns = cols

# %%
pred_df.head()
# Out:
#          id  concrete_cement  healthy_metal  incomplete  irregular_metal  \
# 0  7a4d9168         0.033468       0.958466    0.000657         0.006149
# 1  7a4ae922         0.004417       0.894727    0.002138         0.096884
# 2  7a48ca98         0.003339       0.233773    0.013359         0.748489
# 3  7a49c614         0.000494       0.859539    0.000788         0.138634
# 4  7a4dd4f2         0.000515       0.912010    0.000831         0.081663
#
#       other
# 0  0.001259
# 1  0.001835
# 2  0.001040
# 3  0.000545
# 4  0.004982

# %% [markdown]
# Required format:
#
# <pre>
# id	concrete_cement	healthy_metal	incomplete	irregular_metal	other
# 7a4d630a	0.9	0	0	0	0
# 7a4bbbd6	0.9	0	0	0	0
# 7a4ac744	0.9	0	0	0	0
# 7a4881fa	0.9	0	0	0	0
# 7a4aa4a8	0.9	0	0	0	0
# </pre>

# %%
pred_df = pd.read_csv(data_dir/f'submissions/stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.csv')

# %%
pred_df.head()
# Out:
#          id  concrete_cement  healthy_metal  incomplete  irregular_metal  \
# 0  7a4d9168         0.033468       0.958466    0.000657         0.006149
# 1  7a4ae922         0.004417       0.894727    0.002138         0.096884
# 2  7a48ca98         0.003339       0.233773    0.013359         0.748489
# 3  7a49c614         0.000494       0.859539    0.000788         0.138634
# 4  7a4dd4f2         0.000515       0.912010    0.000831         0.081663
#
#       other
# 0  0.001259
# 1  0.001835
# 2  0.001040
# 3  0.000545
# 4  0.004982

# %%
pred_ids=pred_df['id'].values.tolist()

#  '7a4edcd0',
#  '7a4ebdc2',
#  '7a48811e',
#  '7a4a5bce',
#  '7a49481a',
#  '7a4f4896',
#  '7a4fc91a',
#  '7a512968',
#  '7a4945a4',
#  '7a4a55e8',
#  '7a493190',
#  '7a462a0e',
#  '7a4824ee',
#  '7a4de500',
#  '7a462c34',
#  '7a51be00',
#  '7a47de94',
#  '7a47a7bc',
#  '7a517364',
#  '7a48c548',
#  '7a4b7f7c',
#  '7a452776',
#  '7a49a5e4',
#  '7a508f94',
#  '7a4895fa',
#  '7a472b48',
#  '7a51eab0',
#  '7a4ffea8',
#  '7a492f88',
#  '7a4d2822',
#  '7a50381e',
#  '7a45f034',
#  '7a47e0e2',
#  '7a4f512e',
#  '7a50e91c',
#  '7a4920a6',
#  '7a471856',
#  '7a510ac8',
#  '7a4e2b82',
#  '7a50a6c8',
#  '7a4beb6a',
#  '7a515aaa',
#  '7a4b4246',
#  '7a515a3c',
#  '7a4b9bec',
#  '7a4a3d4c',
#  '7a5092c8',
#  '7a4f3752',
#  '7a48f1b2',
#  '7a5038f0',
#  '7a44ff26',
#  '7a4b0cc2',
#  ...]

# %%
assert set(pred_ids)==set(baseline_ids)

# %% [markdown]
# #### sort by baseline ids

# %%
pred_df['id_cat'] = pd.Categorical(
    pred_df['id'], 
    categories=baseline_ids, 
    ordered=True
)

# %%
pred_df.head()
# Out:
#          id  concrete_cement  healthy_metal  incomplete  irregular_metal  \
# 0  7a4d9168         0.033468       0.958466    0.000657         0.006149
# 1  7a4ae922         0.004417       0.894727    0.002138         0.096884
# 2  7a48ca98         0.003339       0.233773    0.013359         0.748489
# 3  7a49c614         0.000494       0.859539    0.000788         0.138634
# 4  7a4dd4f2         0.000515       0.912010    0.000831         0.081663
#
#       other    id_cat
# 0  0.001259  7a4d9168
# 1  0.001835  7a4ae922
# 2  0.001040  7a48ca98
# 3  0.000545  7a49c614
# 4  0.004982  7a4dd4f2

# %%
pred_df=pred_df.sort_values('id_cat')

# %%
pred_df.head()
# Out:
#             id  concrete_cement  healthy_metal  incomplete  irregular_metal  \
# 716   7a4d630a         0.013808       0.980777    0.000303         0.003716
# 764   7a4bbbd6         0.000810       0.949852    0.000470         0.048376
# 1841  7a4ac744         0.001608       0.855418    0.001628         0.140389
# 3363  7a4881fa         0.004803       0.234743    0.006764         0.752769
# 133   7a4aa4a8         0.004477       0.706235    0.003069         0.283955
#
#          other    id_cat
# 716   0.001395  7a4d630a
# 764   0.000491  7a4bbbd6
# 1841  0.000957  7a4ac744
# 3363  0.000920  7a4881fa
# 133   0.002263  7a4aa4a8

# %%
pred_df.drop(columns=['id_cat'],inplace=True)

# %%
pred_df.to_csv(data_dir/f'submissions/stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.csv', index=False)

# %%
### Submission 2: 0.4461

# %%
arch_name = 'rn50'
pred_df=pd.read_csv(data_dir/f'submissions/stage-2-{arch_name}-{NB_NUM}-{MODEL_NAME}-{DATE}-{UID}.csv')

# %%
pred_df.drop(columns=['id'],inplace=True)
classes=pred_df.idxmax(axis=1)
pd.value_counts(classes).plot(kind="bar")
